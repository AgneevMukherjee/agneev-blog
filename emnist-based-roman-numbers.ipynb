# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2 as cv
import os
from os import path
import math
import re
import random

# %%
# !apt-get install zip
# Out:
# zip is already the newest version (3.0-11build1).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %%
if path.exists('/kaggle/working/output/')==False:
    os.mkdir('/kaggle/working/output/')

# %%
output_folder = '/kaggle/working/output/'

# %%
def gaussian_noise(image):
    noise = np.zeros((image.shape[0], image.shape[1]),dtype=np.uint8)
    cv.randn(noise, 128, 20)
    noise = (noise*random.uniform(0, 0.1)).astype(np.uint8)
    return noise

# %%
def uniform_noise(image):
    noise = np.zeros((image.shape[0], image.shape[1]),dtype=np.uint8)
    cv.randu(noise,0,255)
    noise = (noise*random.uniform(0, 0.1)).astype(np.uint8)
    return noise

# %%
def impulse_noise(image):
    noise = np.zeros((image.shape[0], image.shape[1]),dtype=np.uint8)
    ret,noise = cv.threshold(noise,250,255,cv.THRESH_BINARY)
    noise = (noise*random.uniform(0, 0.1)).astype(np.uint8)
    return noise

# %%
def darkener(img):
    row,col = img.shape
    r = 0
    while r<row:
        c = 0
        while c<col:
            if img[r][c]<175:
                img[r][c]=50
            c+=1
        r+=1
    return img

# %%
def darkener2(img):
    row,col = img.shape
    r = 0
    while r<row:
        c = 0
        while c<col:
            if img[r][c]<200:
                img[r][c]=50
            c+=1
        r+=1
    return img

# %%
def darkener3(img):
    row,col = img.shape
    r = 0
    while r<row:
        c = 0
        while c<col:
            if img[r][c]<190:
                img[r][c]=50
            c+=1
        r+=1
    return img

# %%
def add_noise(img):
  
    # Getting the dimensions of the image
    row , col = img.shape
      
    # Randomly pick some pixels in the
    # image for coloring them white
    # Pick a random number between 3 and 10
    number_of_pixels = random.randint(3, 10)
    for i in range(number_of_pixels):
        
        # Pick a random y coordinate
        y_coord=random.randint(0, row - 1)
          
        # Pick a random x coordinate
        x_coord=random.randint(0, col - 1)
          
        # Colour that pixel to white
        img[y_coord][x_coord] = 205
        
    # Randomly pick some pixels in
    # the image for coloring them black
    # Pick a random number between 3 and 10
    number_of_pixels = random.randint(3 , 10)
    for i in range(number_of_pixels):
        
        # Pick a random y coordinate
        y_coord=random.randint(0, row - 1)
          
        # Pick a random x coordinate
        x_coord=random.randint(0, col - 1)
          
        # Colour that pixel to black
        img[y_coord][x_coord] = 50
                
    img = img.astype(np.uint8)
    img = cv.merge((img,img,img))
    return img

# %%
train_df = pd.read_csv('../input/emnist/emnist-byclass-train.csv', header=None)

# %%
X_train = train_df.loc[:, 1:]
y_train = train_df.loc[:, 0]

# %%
label_map = pd.read_csv("../input/emnist/emnist-byclass-mapping.txt", 
                        delimiter = ' ', 
                        index_col=0, 
                        header=None, 
                        squeeze=True)

# %%
label_dictionary = {}
for index, label in enumerate(label_map):
    label_dictionary[index] = chr(label)

# %%
def reshape_and_rotate(image):
    W = 28
    H = 28
    image = image.reshape(W, H)
    image = np.fliplr(image)
    image = np.rot90(image)
    return image

# %%
# Capital 1s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==18:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        noisy_image1 = cv.add(img,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        noisy = add_noise(noisy_image3)
        cv.imwrite(os.path.join(output_folder, f'1_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making capital 2s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==18:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        rows,cols = img.shape[:2]
        M = np.float32([[1,0,8],[0,1,0]])
        dst = cv.warpAffine(img,M,(cols,rows))
        dst2 = cv.rectangle(dst, (0,0), (12,28), (255), -1)
        dst3 = cv.addWeighted(img, 0.5, dst2, 0.5, 0.0)
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        noisy_image1 = cv.add(dst3,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        dark_image = darkener(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'2_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making capital 3s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==18:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        rows,cols = img.shape[:2]
        M = np.float32([[1,0,8],[0,1,0]])
        M_M = np.float32([[1,0,-8],[0,1,0]])
        dst = cv.warpAffine(img,M,(cols,rows))
        dst_dst = cv.warpAffine(img,M_M,(cols,rows))
        dst2 = cv.rectangle(dst, (0,0), (12,28), (255), -1)
        dst_dst2 = cv.rectangle(dst_dst, (20,0), (28,28), (255), -1)  
        dst3 = cv.addWeighted(img, 0.5, dst2, 0.5, 0.0)
        dst_dst3 = cv.addWeighted(dst3, 0.67, dst_dst2, 0.33, 0.0)
        noisy_image1 = cv.add(dst_dst3,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        dark_image = darkener2(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'3_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making capital 4s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==18:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        M = np.float32([[1,0,7],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==31:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(cols,rows))
        dst_dst = cv.warpAffine(img2,M,(cols,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (12,28), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (28,28), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)        
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        noisy_image1 = cv.add(dst3,gaussian_noise(img1))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img1))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img1))
        dark_image = darkener(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'4_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==200:break
    i+=inc

# %%
# Capital 5s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==31:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        noisy_image1 = cv.add(img,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        noisy = add_noise(noisy_image3)
        cv.imwrite(os.path.join(output_folder, f'5_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making capital 6s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==31:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        M = np.float32([[1,0,7],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==18:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(cols,rows))
        dst_dst = cv.warpAffine(img2,M,(cols,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (12,28), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (28,28), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)        
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        noisy_image1 = cv.add(dst3,gaussian_noise(img1))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img1))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img1))
        dark_image = darkener(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'6_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making capital 7s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==31:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        exp = cols+4
        M = np.float32([[1,0,7],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        M_M_M = np.float32([[1,0,14],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==18:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                img3 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img3 = cv.bitwise_not(img3)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(exp,rows))
        dst_dst = cv.warpAffine(img2,M,(exp,rows))
        dst_dst_dst = cv.warpAffine(img3,M_M_M,(exp,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (16,32), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (32,32), (255), -1)  
        dst_dst_dst2 = cv.rectangle(dst_dst_dst, (0,0), (16,32), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)      
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        dst4 = cv.addWeighted(dst_dst_dst2, 0.33, dst3, 0.67, 0.0)      
        mask=cv.inRange(dst4,(0),(13))
        dst4[mask>0]=(0)
        noisy_image1 = cv.add(dst4,gaussian_noise(dst4))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(dst4))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(dst4))
        dark_image = darkener2(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'7_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making capital 8s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==31:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        exp = cols+8
        M = np.float32([[1,0,8],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        M_M_M = np.float32([[1,0,14],[0,1,0]])
        M_4 = np.float32([[1,0,21],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==18:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                img3 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img3 = cv.bitwise_not(img3)
                img4 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img4 = cv.bitwise_not(img4)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(exp,rows))
        dst_dst = cv.warpAffine(img2,M,(exp,rows))
        dst_dst_dst = cv.warpAffine(img3,M_M_M,(exp,rows))
        dst_sqrd = cv.warpAffine(img3,M_4,(exp,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (16,36), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (36,36), (255), -1)  
        dst_dst_dst2 = cv.rectangle(dst_dst_dst, (0,0), (16,36), (255), -1)  
        dst_sqrd_2 = cv.rectangle(dst_sqrd, (20,0), (0,36), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)      
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        dst4 = cv.addWeighted(dst_dst_dst2, 0.33, dst3, 0.67, 0.0)      
        mask=cv.inRange(dst4,(0),(13))
        dst4[mask>0]=(0)
        dst5 = cv.addWeighted(dst_sqrd_2, 0.25, dst4, 0.75, 0.0)      
        mask=cv.inRange(dst5,(0),(13))
        dst5[mask>0]=(0)
        
        noisy_image1 = cv.add(dst5,gaussian_noise(dst5))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(dst5))
        noisy_image3 = cv.add(dst5,impulse_noise(dst5))
        dark_image = darkener2(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'8_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making capital 9s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==18:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        M = np.float32([[1,0,7],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==33:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(cols,rows))
        dst_dst = cv.warpAffine(img2,M,(cols,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (12,28), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (28,28), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)        
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        noisy_image1 = cv.add(dst3,gaussian_noise(img1))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img1))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img1))
        dark_image = darkener(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'9_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==200:break
    i+=inc

# %%
# Capital 10s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==33:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        noisy_image1 = cv.add(img,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        noisy = add_noise(noisy_image3)
        cv.imwrite(os.path.join(output_folder, f'10_cap_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Small 1s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==44:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        noisy_image1 = cv.add(img,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        noisy = add_noise(noisy_image3)
        cv.imwrite(os.path.join(output_folder, f'1_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making small 2s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==44:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        rows,cols = img.shape[:2]
        M = np.float32([[1,0,8],[0,1,0]])
        dst = cv.warpAffine(img,M,(cols,rows))
        dst2 = cv.rectangle(dst, (0,0), (12,28), (255), -1)
        dst3 = cv.addWeighted(img, 0.5, dst2, 0.5, 0.0)
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        noisy_image1 = cv.add(dst3,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        dark_image = darkener(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'2_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making small 3s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==44:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        rows,cols = img.shape[:2]
        M = np.float32([[1,0,8],[0,1,0]])
        M_M = np.float32([[1,0,-8],[0,1,0]])
        dst = cv.warpAffine(img,M,(cols,rows))
        dst_dst = cv.warpAffine(img,M_M,(cols,rows))
        dst2 = cv.rectangle(dst, (0,0), (12,28), (255), -1)
        dst_dst2 = cv.rectangle(dst_dst, (20,0), (28,28), (255), -1)  
        dst3 = cv.addWeighted(img, 0.5, dst2, 0.5, 0.0)
        dst_dst3 = cv.addWeighted(dst3, 0.67, dst_dst2, 0.33, 0.0)
        noisy_image1 = cv.add(dst_dst3,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        dark_image = darkener2(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'3_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making small 4s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==44:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        M = np.float32([[1,0,7],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==57:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(cols,rows))
        dst_dst = cv.warpAffine(img2,M,(cols,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (12,28), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (28,28), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)        
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        noisy_image1 = cv.add(dst3,gaussian_noise(img1))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img1))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img1))
        dark_image = darkener(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'4_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==200:break
    i+=inc

# %%
# Small 5s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==57:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        noisy_image1 = cv.add(img,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        noisy = add_noise(noisy_image3)
        cv.imwrite(os.path.join(output_folder, f'5_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making capital 6s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==57:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        M = np.float32([[1,0,7],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==44:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(cols,rows))
        dst_dst = cv.warpAffine(img2,M,(cols,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (12,28), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (28,28), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)        
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        noisy_image1 = cv.add(dst3,gaussian_noise(img1))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img1))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img1))
        dark_image = darkener(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'6_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making small 7s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==57:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        exp = cols+4
        M = np.float32([[1,0,7],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        M_M_M = np.float32([[1,0,14],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==44:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                img3 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img3 = cv.bitwise_not(img3)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(exp,rows))
        dst_dst = cv.warpAffine(img2,M,(exp,rows))
        dst_dst_dst = cv.warpAffine(img3,M_M_M,(exp,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (16,32), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (32,32), (255), -1)  
        dst_dst_dst2 = cv.rectangle(dst_dst_dst, (0,0), (16,32), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)      
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        dst4 = cv.addWeighted(dst_dst_dst2, 0.33, dst3, 0.67, 0.0)      
        mask=cv.inRange(dst4,(0),(13))
        dst4[mask>0]=(0)
        noisy_image1 = cv.add(dst4,gaussian_noise(dst4))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(dst4))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(dst4))
        dark_image = darkener2(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'7_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making small 8s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==57:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        exp = cols+8
        M = np.float32([[1,0,8],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        M_M_M = np.float32([[1,0,14],[0,1,0]])
        M_4 = np.float32([[1,0,21],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==44:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                img3 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img3 = cv.bitwise_not(img3)
                img4 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img4 = cv.bitwise_not(img4)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(exp,rows))
        dst_dst = cv.warpAffine(img2,M,(exp,rows))
        dst_dst_dst = cv.warpAffine(img3,M_M_M,(exp,rows))
        dst_sqrd = cv.warpAffine(img3,M_4,(exp,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (16,36), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (36,36), (255), -1)  
        dst_dst_dst2 = cv.rectangle(dst_dst_dst, (0,0), (16,36), (255), -1)  
        dst_sqrd_2 = cv.rectangle(dst_sqrd, (20,0), (0,36), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)      
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        dst4 = cv.addWeighted(dst_dst_dst2, 0.33, dst3, 0.67, 0.0)      
        mask=cv.inRange(dst4,(0),(13))
        dst4[mask>0]=(0)
        dst5 = cv.addWeighted(dst_sqrd_2, 0.25, dst4, 0.75, 0.0)      
        mask=cv.inRange(dst5,(0),(13))
        dst5[mask>0]=(0)
        
        noisy_image1 = cv.add(dst5,gaussian_noise(dst5))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(dst5))
        noisy_image3 = cv.add(dst5,impulse_noise(dst5))
        dark_image = darkener2(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'8_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# Making small 9s
i=0
j=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==44:
        n+=1
        img1 = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img1 = cv.bitwise_not(img1)
        rows,cols = img1.shape[:2]
        M = np.float32([[1,0,7],[0,1,0]])
        M_M = np.float32([[1,0,-7],[0,1,0]])
        while j<len(y_train):
            if y_train[j]==59:
                img2 = reshape_and_rotate(X_train.iloc[j].values).astype('uint8')
                img2 = cv.bitwise_not(img2)
                j+=inc
                break
            j+=inc

        dst = cv.warpAffine(img1,M_M,(cols,rows))
        dst_dst = cv.warpAffine(img2,M,(cols,rows))
        dst2 = cv.rectangle(dst_dst, (0,0), (12,28), (255), -1)
        dst_dst2 = cv.rectangle(dst, (20,0), (28,28), (255), -1)  
        dst3 = cv.addWeighted(dst_dst2, 0.5, dst2, 0.5, 0.0)        
        mask=cv.inRange(dst3,(0),(13))
        dst3[mask>0]=(0)
        noisy_image1 = cv.add(dst3,gaussian_noise(img1))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img1))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img1))
        dark_image = darkener(noisy_image3)
        noisy = add_noise(dark_image)
        cv.imwrite(os.path.join(output_folder, f'9_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==200:break
    i+=inc

# %%
# Small 10s
i=0
n=0
while i<len(y_train):
    inc = random.randint(1, 5)
    if y_train[i]==59:
        n+=1
        img = reshape_and_rotate(X_train.iloc[i].values).astype('uint8')
        img = cv.bitwise_not(img)
        noisy_image1 = cv.add(img,gaussian_noise(img))
        noisy_image2 = cv.add(noisy_image1,uniform_noise(img))
        noisy_image3 = cv.add(noisy_image2,impulse_noise(img))
        noisy = add_noise(noisy_image3)
        cv.imwrite(os.path.join(output_folder, f'10_small_{str(n)}.png'), noisy,  [cv.IMWRITE_PNG_COMPRESSION, 9])
        if n<6:
            plt.imshow(noisy)
            plt.show()
    if n==500:break
    i+=inc

# %%
# !zip -r output.zip /kaggle/working/output/
# Out:
#   adding: kaggle/working/output/ (stored 0%)
#   adding: kaggle/working/output/2_small_354.png (stored 0%)
#   adding: kaggle/working/output/8_small_181.png (stored 0%)
#   adding: kaggle/working/output/1_cap_377.png (stored 0%)
#   adding: kaggle/working/output/3_cap_97.png (stored 0%)
#   adding: kaggle/working/output/10_small_121.png (stored 0%)
#   adding: kaggle/working/output/1_small_454.png (stored 0%)
#   adding: kaggle/working/output/5_cap_358.png (stored 0%)
#   adding: kaggle/working/output/6_small_315.png (stored 0%)
#   adding: kaggle/working/output/9_cap_65.png (stored 0%)
#   adding: kaggle/working/output/6_cap_442.png (stored 0%)
#   adding: kaggle/working/output/10_small_145.png (stored 0%)
#   adding: kaggle/working/output/9_cap_22.png (stored 0%)
#   adding: kaggle/working/output/3_cap_239.png (stored 0%)
#   adding: kaggle/working/output/10_small_208.png (stored 0%)
#   adding: kaggle/working/output/5_cap_269.png (stored 0%)
#   adding: kaggle/working/output/4_cap_102.png (stored 0%)
#   adding: kaggle/working/output/2_cap_496.png (stored 0%)
#   adding: kaggle/working/output/9_cap_133.png (stored 0%)
#   adding: kaggle/working/output/2_cap_451.png (stored 0%)
#   adding: kaggle/working/output/1_cap_347.png (stored 0%)
#   adding: kaggle/working/output/5_small_51.png (stored 0%)
#   adding: kaggle/working/output/2_small_135.png (stored 0%)
#   adding: kaggle/working/output/8_cap_190.png (stored 0%)
#   adding: kaggle/working/output/2_cap_428.png (stored 0%)
#   adding: kaggle/working/output/8_small_99.png (stored 0%)
#   adding: kaggle/working/output/5_cap_241.png (stored 0%)
#   adding: kaggle/working/output/2_cap_442.png (stored 0%)
#   adding: kaggle/working/output/5_cap_410.png (stored 0%)
#   adding: kaggle/working/output/10_cap_395.png (stored 0%)
#   adding: kaggle/working/output/4_cap_103.png (stored 0%)
#   adding: kaggle/working/output/8_small_398.png (stored 0%)
#   adding: kaggle/working/output/2_small_276.png (stored 0%)
#   adding: kaggle/working/output/1_small_132.png (stored 0%)
#   adding: kaggle/working/output/3_cap_37.png (stored 0%)
#   adding: kaggle/working/output/5_small_263.png (stored 0%)
#   adding: kaggle/working/output/6_small_306.png (stored 0%)
#   adding: kaggle/working/output/3_small_243.png (stored 0%)
#   adding: kaggle/working/output/4_cap_12.png (stored 0%)
#   adding: kaggle/working/output/5_cap_145.png (stored 0%)
#   adding: kaggle/working/output/3_cap_322.png (stored 0%)
#   adding: kaggle/working/output/9_cap_137.png (stored 0%)
#   adding: kaggle/working/output/3_small_331.png (stored 0%)
#   adding: kaggle/working/output/7_cap_473.png (stored 0%)
#   adding: kaggle/working/output/7_cap_417.png (stored 0%)
#   adding: kaggle/working/output/9_cap_54.png (stored 0%)
#   adding: kaggle/working/output/6_cap_364.png (stored 0%)
#   adding: kaggle/working/output/1_small_376.png (stored 0%)
#   adding: kaggle/working/output/1_cap_229.png (stored 0%)
#   adding: kaggle/working/output/2_small_329.png (stored 0%)
#   adding: kaggle/working/output/7_cap_180.png (stored 0%)
#   adding: kaggle/working/output/6_small_275.png (stored 0%)
#   adding: kaggle/working/output/6_cap_472.png (stored 0%)
#   adding: kaggle/working/output/5_cap_409.png (stored 0%)
#   adding: kaggle/working/output/7_cap_498.png (stored 0%)
#   adding: kaggle/working/output/9_small_183.png (stored 0%)
#   adding: kaggle/working/output/4_small_169.png (stored 0%)
#   adding: kaggle/working/output/7_cap_51.png (stored 0%)
#   adding: kaggle/working/output/6_small_412.png (stored 0%)
#   adding: kaggle/working/output/8_cap_306.png (stored 0%)
#   adding: kaggle/working/output/9_cap_112.png (stored 0%)
#   adding: kaggle/working/output/7_cap_259.png (stored 0%)
#   adding: kaggle/working/output/7_small_37.png (stored 0%)
#   adding: kaggle/working/output/9_small_88.png (stored 0%)
#   adding: kaggle/working/output/10_small_351.png (stored 0%)
#   adding: kaggle/working/output/6_cap_427.png (stored 0%)
#   adding: kaggle/working/output/3_small_192.png (stored 0%)
#   adding: kaggle/working/output/4_small_132.png (stored 0%)
#   adding: kaggle/working/output/2_cap_294.png (stored 0%)
#   adding: kaggle/working/output/9_cap_53.png (stored 0%)
#   adding: kaggle/working/output/4_cap_31.png (stored 0%)
#   adding: kaggle/working/output/6_small_171.png (stored 0%)
#   adding: kaggle/working/output/9_small_9.png (stored 0%)
#   adding: kaggle/working/output/7_cap_206.png (stored 0%)
#   adding: kaggle/working/output/1_small_165.png (stored 0%)
#   adding: kaggle/working/output/7_small_104.png (stored 0%)
#   adding: kaggle/working/output/3_cap_361.png (stored 0%)
#   adding: kaggle/working/output/8_cap_393.png (stored 0%)
#   adding: kaggle/working/output/5_cap_395.png (stored 0%)
#   adding: kaggle/working/output/10_cap_57.png (stored 0%)
#   adding: kaggle/working/output/1_cap_394.png (stored 0%)
#   adding: kaggle/working/output/1_cap_404.png (stored 0%)
#   adding: kaggle/working/output/10_small_344.png (stored 0%)
#   adding: kaggle/working/output/8_small_364.png (stored 0%)
#   adding: kaggle/working/output/8_cap_343.png (stored 0%)
#   adding: kaggle/working/output/3_small_265.png (stored 0%)
#   adding: kaggle/working/output/2_small_497.png (stored 0%)
#   adding: kaggle/working/output/6_small_95.png (stored 0%)
#   adding: kaggle/working/output/3_cap_143.png (stored 0%)
#   adding: kaggle/working/output/2_small_346.png (stored 0%)
#   adding: kaggle/working/output/5_cap_14.png (stored 0%)
#   adding: kaggle/working/output/4_cap_87.png (stored 0%)
#   adding: kaggle/working/output/1_cap_2.png (stored 0%)
#   adding: kaggle/working/output/6_cap_181.png (stored 0%)
#   adding: kaggle/working/output/8_cap_124.png (stored 0%)
#   adding: kaggle/working/output/1_small_110.png (stored 0%)
#   adding: kaggle/working/output/2_small_321.png (stored 0%)
#   adding: kaggle/working/output/2_cap_238.png (stored 0%)
#   adding: kaggle/working/output/10_small_51.png (stored 0%)
#   adding: kaggle/working/output/7_small_33.png (stored 0%)
#   adding: kaggle/working/output/3_small_103.png (stored 0%)
#   adding: kaggle/working/output/3_cap_158.png (stored 0%)
#   adding: kaggle/working/output/2_cap_6.png (stored 0%)
#   adding: kaggle/working/output/3_cap_432.png (stored 0%)
#   adding: kaggle/working/output/8_small_390.png (stored 0%)
#   adding: kaggle/working/output/1_cap_152.png (stored 0%)
#   adding: kaggle/working/output/8_small_68.png (stored 0%)
#   adding: kaggle/working/output/7_cap_404.png (stored 0%)
#   adding: kaggle/working/output/4_small_4.png (stored 0%)
#   adding: kaggle/working/output/3_cap_70.png (stored 0%)
#   adding: kaggle/working/output/8_small_192.png (stored 0%)
#   adding: kaggle/working/output/1_cap_441.png (stored 0%)
#   adding: kaggle/working/output/1_small_270.png (stored 0%)
#   adding: kaggle/working/output/8_cap_453.png (stored 0%)
#   adding: kaggle/working/output/10_cap_67.png (stored 0%)
#   adding: kaggle/working/output/1_small_187.png (stored 0%)
#   adding: kaggle/working/output/5_small_414.png (stored 0%)
#   adding: kaggle/working/output/3_cap_90.png (stored 0%)
#   adding: kaggle/working/output/2_small_104.png (stored 0%)
#   adding: kaggle/working/output/1_cap_11.png (stored 0%)
#   adding: kaggle/working/output/7_cap_325.png (stored 0%)
#   adding: kaggle/working/output/2_small_414.png (stored 0%)
#   adding: kaggle/working/output/1_small_445.png (stored 0%)
#   adding: kaggle/working/output/5_cap_250.png (stored 0%)
#   adding: kaggle/working/output/7_cap_419.png (stored 0%)
#   adding: kaggle/working/output/7_small_343.png (stored 0%)
#   adding: kaggle/working/output/7_small_430.png (stored 0%)
#   adding: kaggle/working/output/9_small_74.png (stored 0%)
#   adding: kaggle/working/output/2_small_108.png (stored 0%)
#   adding: kaggle/working/output/2_cap_188.png (stored 0%)
#   adding: kaggle/working/output/10_cap_10.png (stored 0%)
#   adding: kaggle/working/output/3_cap_54.png (stored 0%)
#   adding: kaggle/working/output/9_cap_154.png (stored 0%)
#   adding: kaggle/working/output/5_small_232.png (stored 0%)
#   adding: kaggle/working/output/2_cap_487.png (stored 0%)
#   adding: kaggle/working/output/8_cap_270.png (stored 0%)
#   adding: kaggle/working/output/9_cap_158.png (stored 0%)
#   adding: kaggle/working/output/6_small_283.png (stored 0%)
#   adding: kaggle/working/output/5_cap_108.png (stored 0%)
#   adding: kaggle/working/output/4_cap_128.png (stored 0%)
#   adding: kaggle/working/output/10_cap_208.png (stored 0%)
#   adding: kaggle/working/output/8_small_153.png (stored 0%)
#   adding: kaggle/working/output/3_small_24.png (stored 0%)
#   adding: kaggle/working/output/5_small_149.png (stored 0%)
#   adding: kaggle/working/output/5_cap_392.png (stored 0%)
#   adding: kaggle/working/output/7_cap_2.png (stored 0%)
#   adding: kaggle/working/output/7_small_190.png (stored 0%)
#   adding: kaggle/working/output/1_cap_356.png (stored 0%)
#   adding: kaggle/working/output/3_cap_95.png (stored 0%)
#   adding: kaggle/working/output/10_cap_14.png (stored 0%)
#   adding: kaggle/working/output/5_small_218.png (stored 0%)
#   adding: kaggle/working/output/10_cap_29.png (stored 0%)
#   adding: kaggle/working/output/2_cap_484.png (stored 0%)
#   adding: kaggle/working/output/8_cap_291.png (stored 0%)
#   adding: kaggle/working/output/4_cap_18.png (stored 0%)
#   adding: kaggle/working/output/8_cap_25.png (stored 0%)
#   adding: kaggle/working/output/9_small_21.png (stored 0%)
#   adding: kaggle/working/output/10_small_419.png (stored 0%)
#   adding: kaggle/working/output/10_small_467.png (stored 0%)
#   adding: kaggle/working/output/10_cap_126.png (stored 0%)
#   adding: kaggle/working/output/5_small_196.png (stored 0%)
#   adding: kaggle/working/output/8_small_226.png (stored 0%)
#   adding: kaggle/working/output/6_cap_460.png (stored 0%)
#   adding: kaggle/working/output/6_cap_49.png (stored 0%)
#   adding: kaggle/working/output/6_small_57.png (stored 0%)
#   adding: kaggle/working/output/6_cap_468.png (stored 0%)
#   adding: kaggle/working/output/9_small_48.png (stored 0%)
#   adding: kaggle/working/output/9_small_95.png (stored 0%)
#   adding: kaggle/working/output/8_cap_232.png (stored 0%)
#   adding: kaggle/working/output/8_cap_300.png (stored 0%)
#   adding: kaggle/working/output/6_small_199.png (stored 0%)
#   adding: kaggle/working/output/5_cap_232.png (stored 0%)
#   adding: kaggle/working/output/7_small_113.png (stored 0%)
#   adding: kaggle/working/output/2_small_391.png (stored 0%)
#   adding: kaggle/working/output/1_cap_415.png (stored 0%)
#   adding: kaggle/working/output/3_small_208.png (stored 0%)
#   adding: kaggle/working/output/3_cap_326.png (stored 0%)
#   adding: kaggle/working/output/3_cap_109.png (stored 0%)
#   adding: kaggle/working/output/9_cap_141.png (stored 0%)
#   adding: kaggle/working/output/8_small_234.png (stored 0%)
#   adding: kaggle/working/output/1_cap_197.png (stored 0%)
#   adding: kaggle/working/output/4_small_98.png (stored 0%)
#   adding: kaggle/working/output/2_small_229.png (stored 0%)
#   adding: kaggle/working/output/6_small_318.png (stored 0%)
#   adding: kaggle/working/output/2_cap_495.png (stored 0%)
#   adding: kaggle/working/output/7_small_349.png (stored 0%)
#   adding: kaggle/working/output/4_small_27.png (stored 0%)
#   adding: kaggle/working/output/2_small_383.png (stored 0%)
#   adding: kaggle/working/output/2_cap_144.png (stored 0%)
#   adding: kaggle/working/output/1_cap_49.png (stored 0%)
#   adding: kaggle/working/output/5_cap_31.png (stored 0%)
#   adding: kaggle/working/output/7_cap_33.png (stored 0%)
#   adding: kaggle/working/output/4_small_14.png (stored 0%)
#   adding: kaggle/working/output/10_small_110.png (stored 0%)
#   adding: kaggle/working/output/1_small_190.png (stored 0%)
#   adding: kaggle/working/output/2_small_191.png (stored 0%)
#   adding: kaggle/working/output/1_small_431.png (stored 0%)
#   adding: kaggle/working/output/8_small_25.png (stored 0%)
#   adding: kaggle/working/output/7_cap_288.png (stored 0%)
#   adding: kaggle/working/output/10_cap_301.png (stored 0%)
#   adding: kaggle/working/output/10_cap_182.png (stored 0%)
#   adding: kaggle/working/output/2_cap_483.png (stored 0%)
#   adding: kaggle/working/output/3_small_150.png (stored 0%)
#   adding: kaggle/working/output/2_cap_37.png (stored 0%)
#   adding: kaggle/working/output/8_small_460.png (stored 0%)
#   adding: kaggle/working/output/8_cap_128.png (stored 0%)
#   adding: kaggle/working/output/10_cap_265.png (stored 0%)
#   adding: kaggle/working/output/3_cap_258.png (stored 0%)
#   adding: kaggle/working/output/1_small_353.png (stored 0%)
#   adding: kaggle/working/output/5_small_297.png (stored 0%)
#   adding: kaggle/working/output/8_cap_412.png (stored 0%)
#   adding: kaggle/working/output/7_cap_416.png (stored 0%)
#   adding: kaggle/working/output/2_small_170.png (stored 0%)
#   adding: kaggle/working/output/5_cap_441.png (stored 0%)
#   adding: kaggle/working/output/2_cap_8.png (stored 0%)
#   adding: kaggle/working/output/2_cap_101.png (stored 0%)
#   adding: kaggle/working/output/6_cap_185.png (stored 0%)
#   adding: kaggle/working/output/5_cap_276.png (stored 0%)
#   adding: kaggle/working/output/2_cap_347.png (stored 0%)
#   adding: kaggle/working/output/6_cap_490.png (stored 0%)
#   adding: kaggle/working/output/2_small_365.png (stored 0%)
#   adding: kaggle/working/output/8_cap_23.png (stored 0%)
#   adding: kaggle/working/output/6_cap_381.png (stored 0%)
#   adding: kaggle/working/output/8_cap_89.png (stored 0%)
#   adding: kaggle/working/output/8_cap_379.png (stored 0%)
#   adding: kaggle/working/output/6_small_224.png (stored 0%)
#   adding: kaggle/working/output/1_cap_365.png (stored 0%)
#   adding: kaggle/working/output/10_small_197.png (stored 0%)
#   adding: kaggle/working/output/1_small_218.png (stored 0%)
#   adding: kaggle/working/output/3_small_178.png (stored 0%)
#   adding: kaggle/working/output/7_cap_328.png (stored 0%)
#   adding: kaggle/working/output/7_cap_193.png (stored 0%)
#   adding: kaggle/working/output/7_cap_187.png (stored 0%)
#   adding: kaggle/working/output/10_cap_179.png (stored 0%)
#   adding: kaggle/working/output/1_small_144.png (stored 0%)
#   adding: kaggle/working/output/3_cap_175.png (stored 0%)
#   adding: kaggle/working/output/3_small_66.png (stored 0%)
#   adding: kaggle/working/output/2_cap_498.png (stored 0%)
#   adding: kaggle/working/output/2_small_76.png (stored 0%)
#   adding: kaggle/working/output/10_small_169.png (stored 0%)
#   adding: kaggle/working/output/3_small_479.png (stored 0%)
#   adding: kaggle/working/output/10_small_20.png (stored 0%)
#   adding: kaggle/working/output/3_small_346.png (stored 0%)
#   adding: kaggle/working/output/2_cap_66.png (stored 0%)
#   adding: kaggle/working/output/3_small_260.png (stored 0%)
#   adding: kaggle/working/output/2_small_259.png (stored 0%)
#   adding: kaggle/working/output/10_cap_316.png (stored 0%)
#   adding: kaggle/working/output/8_small_163.png (stored 0%)
#   adding: kaggle/working/output/5_small_111.png (stored 0%)
#   adding: kaggle/working/output/10_small_318.png (stored 0%)
#   adding: kaggle/working/output/1_small_228.png (stored 0%)
#   adding: kaggle/working/output/6_small_6.png (stored 0%)
#   adding: kaggle/working/output/1_small_301.png (stored 0%)
#   adding: kaggle/working/output/8_small_193.png (stored 0%)
#   adding: kaggle/working/output/5_small_108.png (stored 0%)
#   adding: kaggle/working/output/3_small_195.png (stored 0%)
#   adding: kaggle/working/output/1_cap_477.png (stored 0%)
#   adding: kaggle/working/output/1_cap_101.png (stored 0%)
#   adding: kaggle/working/output/5_cap_275.png (stored 0%)
#   adding: kaggle/working/output/10_cap_214.png (stored 0%)
#   adding: kaggle/working/output/5_cap_350.png (stored 0%)
#   adding: kaggle/working/output/1_small_357.png (stored 0%)
#   adding: kaggle/working/output/5_cap_302.png (stored 0%)
#   adding: kaggle/working/output/10_cap_321.png (stored 0%)
#   adding: kaggle/working/output/1_cap_71.png (stored 0%)
#   adding: kaggle/working/output/9_small_52.png (stored 0%)
#   adding: kaggle/working/output/9_cap_46.png (stored 0%)
#   adding: kaggle/working/output/2_small_120.png (stored 0%)
#   adding: kaggle/working/output/3_cap_81.png (stored 0%)
#   adding: kaggle/working/output/2_cap_123.png (stored 0%)
#   adding: kaggle/working/output/7_cap_158.png (stored 0%)
#   adding: kaggle/working/output/8_small_195.png (stored 0%)
#   adding: kaggle/working/output/10_cap_94.png (stored 0%)
#   adding: kaggle/working/output/2_cap_430.png (stored 0%)
#   adding: kaggle/working/output/1_small_126.png (stored 0%)
#   adding: kaggle/working/output/7_cap_293.png (stored 0%)
#   adding: kaggle/working/output/10_cap_474.png (stored 0%)
#   adding: kaggle/working/output/3_cap_334.png (stored 0%)
#   adding: kaggle/working/output/5_cap_247.png (stored 0%)
#   adding: kaggle/working/output/8_cap_106.png (stored 0%)
#   adding: kaggle/working/output/1_small_219.png (stored 0%)
#   adding: kaggle/working/output/10_small_444.png (stored 0%)
#   adding: kaggle/working/output/7_small_239.png (stored 0%)
#   adding: kaggle/working/output/2_small_336.png (stored 0%)
#   adding: kaggle/working/output/6_small_10.png (stored 0%)
#   adding: kaggle/working/output/9_cap_178.png (stored 0%)
#   adding: kaggle/working/output/8_small_275.png (stored 0%)
#   adding: kaggle/working/output/3_cap_341.png (stored 0%)
#   adding: kaggle/working/output/2_cap_130.png (stored 0%)
#   adding: kaggle/working/output/7_cap_335.png (stored 0%)
#   adding: kaggle/working/output/7_small_30.png (stored 0%)
#   adding: kaggle/working/output/5_small_150.png (stored 0%)
#   adding: kaggle/working/output/2_cap_221.png (stored 0%)
#   adding: kaggle/working/output/1_small_453.png (stored 0%)
#   adding: kaggle/working/output/1_small_378.png (stored 0%)
#   adding: kaggle/working/output/7_cap_153.png (stored 0%)
#   adding: kaggle/working/output/3_small_280.png (stored 0%)
#   adding: kaggle/working/output/5_small_17.png (stored 0%)
#   adding: kaggle/working/output/6_small_443.png (stored 0%)
#   adding: kaggle/working/output/9_cap_32.png (stored 0%)
#   adding: kaggle/working/output/9_cap_135.png (stored 0%)
#   adding: kaggle/working/output/1_small_339.png (stored 0%)
#   adding: kaggle/working/output/6_cap_116.png (stored 0%)
#   adding: kaggle/working/output/2_small_100.png (stored 0%)
#   adding: kaggle/working/output/7_small_399.png (stored 0%)
#   adding: kaggle/working/output/10_small_390.png (stored 0%)
#   adding: kaggle/working/output/5_cap_440.png (stored 0%)
#   adding: kaggle/working/output/3_cap_169.png (stored 0%)
#   adding: kaggle/working/output/6_cap_351.png (stored 0%)
#   adding: kaggle/working/output/3_cap_287.png (stored 0%)
#   adding: kaggle/working/output/7_cap_116.png (stored 0%)
#   adding: kaggle/working/output/1_small_497.png (stored 0%)
#   adding: kaggle/working/output/6_cap_96.png (stored 0%)
#   adding: kaggle/working/output/8_small_243.png (stored 0%)
#   adding: kaggle/working/output/7_small_159.png (stored 0%)
#   adding: kaggle/working/output/7_cap_188.png (stored 0%)
#   adding: kaggle/working/output/2_small_438.png (stored 0%)
#   adding: kaggle/working/output/8_small_55.png (stored 0%)
#   adding: kaggle/working/output/1_cap_391.png (stored 0%)
#   adding: kaggle/working/output/1_small_319.png (stored 0%)
#   adding: kaggle/working/output/10_cap_351.png (stored 0%)
#   adding: kaggle/working/output/2_small_171.png (stored 0%)
#   adding: kaggle/working/output/5_small_192.png (stored 0%)
#   adding: kaggle/working/output/10_cap_229.png (stored 0%)
#   adding: kaggle/working/output/3_small_132.png (stored 0%)
#   adding: kaggle/working/output/5_cap_404.png (stored 0%)
#   adding: kaggle/working/output/9_cap_170.png (stored 0%)
#   adding: kaggle/working/output/5_cap_264.png (stored 0%)
#   adding: kaggle/working/output/3_small_49.png (stored 0%)
#   adding: kaggle/working/output/9_small_149.png (stored 0%)
#   adding: kaggle/working/output/1_cap_375.png (stored 0%)
#   adding: kaggle/working/output/1_small_420.png (stored 0%)
#   adding: kaggle/working/output/5_small_493.png (stored 0%)
#   adding: kaggle/working/output/6_small_30.png (stored 0%)
#   adding: kaggle/working/output/5_small_411.png (stored 0%)
#   adding: kaggle/working/output/10_cap_224.png (stored 0%)
#   adding: kaggle/working/output/5_cap_166.png (stored 0%)
#   adding: kaggle/working/output/6_cap_262.png (stored 0%)
#   adding: kaggle/working/output/5_cap_27.png (stored 0%)
#   adding: kaggle/working/output/6_cap_218.png (stored 0%)
#   adding: kaggle/working/output/2_small_87.png (stored 0%)
#   adding: kaggle/working/output/2_cap_339.png (stored 0%)
#   adding: kaggle/working/output/8_cap_500.png (stored 0%)
#   adding: kaggle/working/output/6_cap_487.png (stored 0%)
#   adding: kaggle/working/output/8_cap_20.png (stored 0%)
#   adding: kaggle/working/output/7_small_187.png (stored 0%)
#   adding: kaggle/working/output/4_cap_190.png (stored 0%)
#   adding: kaggle/working/output/10_cap_180.png (stored 0%)
#   adding: kaggle/working/output/6_small_389.png (stored 0%)
#   adding: kaggle/working/output/7_small_330.png (stored 0%)
#   adding: kaggle/working/output/7_cap_118.png (stored 0%)
#   adding: kaggle/working/output/10_small_476.png (stored 0%)
#   adding: kaggle/working/output/10_cap_166.png (stored 0%)
#   adding: kaggle/working/output/6_cap_136.png (stored 0%)
#   adding: kaggle/working/output/3_cap_186.png (stored 0%)
#   adding: kaggle/working/output/7_cap_484.png (stored 0%)
#   adding: kaggle/working/output/9_small_15.png (stored 0%)
#   adding: kaggle/working/output/6_small_232.png (stored 0%)
#   adding: kaggle/working/output/8_cap_285.png (stored 0%)
#   adding: kaggle/working/output/6_cap_497.png (stored 0%)
#   adding: kaggle/working/output/7_small_237.png (stored 0%)
#   adding: kaggle/working/output/10_cap_490.png (stored 0%)
#   adding: kaggle/working/output/6_cap_26.png (stored 0%)
#   adding: kaggle/working/output/2_small_134.png (stored 0%)
#   adding: kaggle/working/output/6_cap_264.png (stored 0%)
#   adding: kaggle/working/output/9_cap_129.png (stored 0%)
#   adding: kaggle/working/output/7_cap_378.png (stored 0%)
#   adding: kaggle/working/output/10_cap_73.png (stored 0%)
#   adding: kaggle/working/output/7_small_376.png (stored 0%)
#   adding: kaggle/working/output/2_small_482.png (stored 0%)
#   adding: kaggle/working/output/4_small_141.png (stored 0%)
#   adding: kaggle/working/output/7_cap_221.png (stored 0%)
#   adding: kaggle/working/output/7_cap_168.png (stored 0%)
#   adding: kaggle/working/output/6_small_201.png (stored 0%)
#   adding: kaggle/working/output/5_cap_110.png (stored 0%)
#   adding: kaggle/working/output/5_small_332.png (stored 0%)
#   adding: kaggle/working/output/3_cap_59.png (stored 0%)
#   adding: kaggle/working/output/8_cap_52.png (stored 0%)
#   adding: kaggle/working/output/3_cap_466.png (stored 0%)
#   adding: kaggle/working/output/3_cap_257.png (stored 0%)
#   adding: kaggle/working/output/1_cap_28.png (stored 0%)
#   adding: kaggle/working/output/9_cap_39.png (stored 0%)
#   adding: kaggle/working/output/1_small_472.png (stored 0%)
#   adding: kaggle/working/output/8_small_419.png (stored 0%)
#   adding: kaggle/working/output/2_small_468.png (stored 0%)
#   adding: kaggle/working/output/2_small_318.png (stored 0%)
#   adding: kaggle/working/output/3_cap_328.png (stored 0%)
#   adding: kaggle/working/output/4_small_100.png (stored 0%)
#   adding: kaggle/working/output/8_cap_137.png (stored 0%)
#   adding: kaggle/working/output/2_cap_424.png (stored 0%)
#   adding: kaggle/working/output/7_cap_400.png (stored 0%)
#   adding: kaggle/working/output/10_small_268.png (stored 0%)
#   adding: kaggle/working/output/8_cap_481.png (stored 0%)
#   adding: kaggle/working/output/5_small_109.png (stored 0%)
#   adding: kaggle/working/output/5_cap_372.png (stored 0%)
#   adding: kaggle/working/output/8_small_288.png (stored 0%)
#   adding: kaggle/working/output/6_cap_450.png (stored 0%)
#   adding: kaggle/working/output/2_small_96.png (stored 0%)
#   adding: kaggle/working/output/2_cap_419.png (stored 0%)
#   adding: kaggle/working/output/6_small_279.png (stored 0%)
#   adding: kaggle/working/output/2_cap_3.png (stored 0%)
#   adding: kaggle/working/output/6_cap_422.png (stored 0%)
#   adding: kaggle/working/output/5_small_413.png (stored 0%)
#   adding: kaggle/working/output/6_cap_269.png (stored 0%)
#   adding: kaggle/working/output/6_small_240.png (stored 0%)
#   adding: kaggle/working/output/3_small_386.png (stored 0%)
#   adding: kaggle/working/output/10_small_180.png (stored 0%)
#   adding: kaggle/working/output/1_cap_243.png (stored 0%)
#   adding: kaggle/working/output/6_cap_148.png (stored 0%)
#   adding: kaggle/working/output/7_small_351.png (stored 0%)
#   adding: kaggle/working/output/6_cap_243.png (stored 0%)
#   adding: kaggle/working/output/1_small_469.png (stored 0%)
#   adding: kaggle/working/output/9_small_45.png (stored 0%)
#   adding: kaggle/working/output/5_cap_238.png (stored 0%)
#   adding: kaggle/working/output/3_cap_342.png (stored 0%)
#   adding: kaggle/working/output/1_cap_144.png (stored 0%)
#   adding: kaggle/working/output/10_small_198.png (stored 0%)
#   adding: kaggle/working/output/2_small_172.png (stored 0%)
#   adding: kaggle/working/output/5_cap_316.png (stored 0%)
#   adding: kaggle/working/output/7_small_312.png (stored 0%)
#   adding: kaggle/working/output/6_small_247.png (stored 0%)
#   adding: kaggle/working/output/5_cap_418.png (stored 0%)
#   adding: kaggle/working/output/3_small_361.png (stored 0%)
#   adding: kaggle/working/output/1_small_212.png (stored 0%)
#   adding: kaggle/working/output/3_small_244.png (stored 0%)
#   adding: kaggle/working/output/1_cap_284.png (stored 0%)
#   adding: kaggle/working/output/4_cap_130.png (stored 0%)
#   adding: kaggle/working/output/2_small_54.png (stored 0%)
#   adding: kaggle/working/output/2_cap_95.png (stored 0%)
#   adding: kaggle/working/output/5_small_267.png (stored 0%)
#   adding: kaggle/working/output/3_cap_217.png (stored 0%)
#   adding: kaggle/working/output/5_cap_277.png (stored 0%)
#   adding: kaggle/working/output/6_small_440.png (stored 0%)
#   adding: kaggle/working/output/5_cap_455.png (stored 0%)
#   adding: kaggle/working/output/6_small_33.png (stored 0%)
#   adding: kaggle/working/output/3_small_78.png (stored 0%)
#   adding: kaggle/working/output/10_cap_211.png (stored 0%)
#   adding: kaggle/working/output/6_small_253.png (stored 0%)
#   adding: kaggle/working/output/6_cap_267.png (stored 0%)
#   adding: kaggle/working/output/7_cap_418.png (stored 0%)
#   adding: kaggle/working/output/7_cap_20.png (stored 0%)
#   adding: kaggle/working/output/7_cap_345.png (stored 0%)
#   adding: kaggle/working/output/4_small_18.png (stored 0%)
#   adding: kaggle/working/output/2_cap_448.png (stored 0%)
#   adding: kaggle/working/output/7_small_115.png (stored 0%)
#   adding: kaggle/working/output/10_small_113.png (stored 0%)
#   adding: kaggle/working/output/2_small_355.png (stored 0%)
#   adding: kaggle/working/output/7_cap_256.png (stored 0%)
#   adding: kaggle/working/output/2_cap_53.png (stored 0%)
#   adding: kaggle/working/output/8_small_188.png (stored 0%)
#   adding: kaggle/working/output/2_small_98.png (stored 0%)
#   adding: kaggle/working/output/5_cap_283.png (stored 0%)
#   adding: kaggle/working/output/7_small_326.png (stored 0%)
#   adding: kaggle/working/output/10_cap_156.png (stored 0%)
#   adding: kaggle/working/output/10_small_102.png (stored 0%)
#   adding: kaggle/working/output/1_small_98.png (stored 0%)
#   adding: kaggle/working/output/1_cap_188.png (stored 0%)
#   adding: kaggle/working/output/5_cap_12.png (stored 0%)
#   adding: kaggle/working/output/6_small_233.png (stored 0%)
#   adding: kaggle/working/output/5_cap_371.png (stored 0%)
#   adding: kaggle/working/output/3_cap_61.png (stored 0%)
#   adding: kaggle/working/output/6_cap_133.png (stored 0%)
#   adding: kaggle/working/output/2_small_433.png (stored 0%)
#   adding: kaggle/working/output/6_cap_57.png (stored 0%)
#   adding: kaggle/working/output/7_small_459.png (stored 0%)
#   adding: kaggle/working/output/10_small_116.png (stored 0%)
#   adding: kaggle/working/output/7_small_495.png (stored 0%)
#   adding: kaggle/working/output/6_cap_184.png (stored 0%)
#   adding: kaggle/working/output/7_cap_63.png (stored 0%)
#   adding: kaggle/working/output/5_cap_430.png (stored 0%)
#   adding: kaggle/working/output/3_small_334.png (stored 0%)
#   adding: kaggle/working/output/2_small_138.png (stored 0%)
#   adding: kaggle/working/output/2_small_286.png (stored 0%)
#   adding: kaggle/working/output/9_small_138.png (stored 0%)
#   adding: kaggle/working/output/2_small_137.png (stored 0%)
#   adding: kaggle/working/output/2_cap_103.png (stored 0%)
#   adding: kaggle/working/output/3_cap_183.png (stored 0%)
#   adding: kaggle/working/output/5_cap_444.png (stored 0%)
#   adding: kaggle/working/output/3_small_366.png (stored 0%)
#   adding: kaggle/working/output/5_small_61.png (stored 0%)
#   adding: kaggle/working/output/3_cap_222.png (stored 0%)
#   adding: kaggle/working/output/5_cap_151.png (stored 0%)
#   adding: kaggle/working/output/5_cap_37.png (stored 0%)
#   adding: kaggle/working/output/9_cap_58.png (stored 0%)
#   adding: kaggle/working/output/10_small_154.png (stored 0%)
#   adding: kaggle/working/output/3_cap_441.png (stored 0%)
#   adding: kaggle/working/output/5_small_211.png (stored 0%)
#   adding: kaggle/working/output/3_cap_21.png (stored 0%)
#   adding: kaggle/working/output/8_cap_323.png (stored 0%)
#   adding: kaggle/working/output/2_cap_417.png (stored 0%)
#   adding: kaggle/working/output/9_small_41.png (stored 0%)
#   adding: kaggle/working/output/2_small_432.png (stored 0%)
#   adding: kaggle/working/output/7_cap_438.png (stored 0%)
#   adding: kaggle/working/output/8_cap_153.png (stored 0%)
#   adding: kaggle/working/output/10_small_398.png (stored 0%)
#   adding: kaggle/working/output/3_small_498.png (stored 0%)
#   adding: kaggle/working/output/8_small_428.png (stored 0%)
#   adding: kaggle/working/output/2_small_281.png (stored 0%)
#   adding: kaggle/working/output/2_cap_274.png (stored 0%)
#   adding: kaggle/working/output/8_small_80.png (stored 0%)
#   adding: kaggle/working/output/3_small_491.png (stored 0%)
#   adding: kaggle/working/output/6_small_409.png (stored 0%)
#   adding: kaggle/working/output/10_small_433.png (stored 0%)
#   adding: kaggle/working/output/5_cap_323.png (stored 0%)
#   adding: kaggle/working/output/5_small_422.png (stored 0%)
#   adding: kaggle/working/output/2_cap_491.png (stored 0%)
#   adding: kaggle/working/output/6_cap_242.png (stored 0%)
#   adding: kaggle/working/output/10_small_130.png (stored 0%)
#   adding: kaggle/working/output/3_cap_46.png (stored 0%)
#   adding: kaggle/working/output/3_small_464.png (stored 0%)
#   adding: kaggle/working/output/6_small_456.png (stored 0%)
#   adding: kaggle/working/output/6_cap_209.png (stored 0%)
#   adding: kaggle/working/output/10_cap_280.png (stored 0%)
#   adding: kaggle/working/output/8_cap_15.png (stored 0%)
#   adding: kaggle/working/output/10_cap_142.png (stored 0%)
#   adding: kaggle/working/output/2_cap_38.png (stored 0%)
#   adding: kaggle/working/output/1_cap_314.png (stored 0%)
#   adding: kaggle/working/output/10_cap_190.png (stored 0%)
#   adding: kaggle/working/output/10_cap_230.png (stored 0%)
#   adding: kaggle/working/output/10_small_229.png (stored 0%)
#   adding: kaggle/working/output/10_cap_17.png (stored 0%)
#   adding: kaggle/working/output/6_small_302.png (stored 0%)
#   adding: kaggle/working/output/10_small_206.png (stored 0%)
#   adding: kaggle/working/output/10_small_202.png (stored 0%)
#   adding: kaggle/working/output/4_small_61.png (stored 0%)
#   adding: kaggle/working/output/7_small_321.png (stored 0%)
#   adding: kaggle/working/output/10_small_498.png (stored 0%)
#   adding: kaggle/working/output/6_cap_492.png (stored 0%)
#   adding: kaggle/working/output/1_cap_336.png (stored 0%)
#   adding: kaggle/working/output/10_cap_372.png (stored 0%)
#   adding: kaggle/working/output/10_small_241.png (stored 0%)
#   adding: kaggle/working/output/8_cap_339.png (stored 0%)
#   adding: kaggle/working/output/5_small_242.png (stored 0%)
#   adding: kaggle/working/output/10_cap_436.png (stored 0%)
#   adding: kaggle/working/output/8_small_204.png (stored 0%)
#   adding: kaggle/working/output/6_cap_320.png (stored 0%)
#   adding: kaggle/working/output/7_cap_195.png (stored 0%)
#   adding: kaggle/working/output/9_cap_117.png (stored 0%)
#   adding: kaggle/working/output/6_small_394.png (stored 0%)
#   adding: kaggle/working/output/10_small_142.png (stored 0%)
#   adding: kaggle/working/output/6_small_223.png (stored 0%)
#   adding: kaggle/working/output/8_small_63.png (stored 0%)
#   adding: kaggle/working/output/10_small_212.png (stored 0%)
#   adding: kaggle/working/output/10_cap_449.png (stored 0%)
#   adding: kaggle/working/output/5_cap_249.png (stored 0%)
#   adding: kaggle/working/output/5_small_404.png (stored 0%)
#   adding: kaggle/working/output/2_cap_271.png (stored 0%)
#   adding: kaggle/working/output/2_small_53.png (stored 0%)
#   adding: kaggle/working/output/7_small_284.png (stored 0%)
#   adding: kaggle/working/output/10_small_305.png (stored 0%)
#   adding: kaggle/working/output/2_small_77.png (stored 0%)
#   adding: kaggle/working/output/6_cap_1.png (stored 0%)
#   adding: kaggle/working/output/8_cap_227.png (stored 0%)
#   adding: kaggle/working/output/7_cap_290.png (stored 0%)
#   adding: kaggle/working/output/6_cap_89.png (stored 0%)
#   adding: kaggle/working/output/1_small_450.png (stored 0%)
#   adding: kaggle/working/output/8_small_345.png (stored 0%)
#   adding: kaggle/working/output/10_cap_7.png (stored 0%)
#   adding: kaggle/working/output/7_small_248.png (stored 0%)
#   adding: kaggle/working/output/3_small_349.png (stored 0%)
#   adding: kaggle/working/output/7_cap_298.png (stored 0%)
#   adding: kaggle/working/output/4_cap_2.png (stored 0%)
#   adding: kaggle/working/output/9_small_151.png (stored 0%)
#   adding: kaggle/working/output/6_cap_66.png (stored 0%)
#   adding: kaggle/working/output/1_cap_221.png (stored 0%)
#   adding: kaggle/working/output/10_small_119.png (stored 0%)
#   adding: kaggle/working/output/9_cap_4.png (stored 0%)
#   adding: kaggle/working/output/1_small_179.png (stored 0%)
#   adding: kaggle/working/output/5_cap_9.png (stored 0%)
#   adding: kaggle/working/output/4_small_64.png (stored 0%)
#   adding: kaggle/working/output/5_cap_136.png (stored 0%)
#   adding: kaggle/working/output/8_cap_483.png (stored 0%)
#   adding: kaggle/working/output/9_cap_192.png (stored 0%)
#   adding: kaggle/working/output/5_cap_191.png (stored 0%)
#   adding: kaggle/working/output/5_cap_426.png (stored 0%)
#   adding: kaggle/working/output/7_cap_482.png (stored 0%)
#   adding: kaggle/working/output/6_small_182.png (stored 0%)
#   adding: kaggle/working/output/2_small_378.png (stored 0%)
#   adding: kaggle/working/output/9_cap_189.png (stored 0%)
#   adding: kaggle/working/output/7_small_195.png (stored 0%)
#   adding: kaggle/working/output/5_small_294.png (stored 0%)
#   adding: kaggle/working/output/6_small_227.png (stored 0%)
#   adding: kaggle/working/output/8_small_144.png (stored 0%)
#   adding: kaggle/working/output/7_cap_189.png (stored 0%)
#   adding: kaggle/working/output/7_small_51.png (stored 0%)
#   adding: kaggle/working/output/7_cap_351.png (stored 0%)
#   adding: kaggle/working/output/3_small_445.png (stored 0%)
#   adding: kaggle/working/output/6_cap_484.png (stored 0%)
#   adding: kaggle/working/output/10_small_311.png (stored 0%)
#   adding: kaggle/working/output/9_small_156.png (stored 0%)
#   adding: kaggle/working/output/7_cap_126.png (stored 0%)
#   adding: kaggle/working/output/1_small_400.png (stored 0%)
#   adding: kaggle/working/output/10_cap_24.png (stored 0%)
#   adding: kaggle/working/output/3_small_343.png (stored 0%)
#   adding: kaggle/working/output/6_small_133.png (stored 0%)
#   adding: kaggle/working/output/1_small_401.png (stored 0%)
#   adding: kaggle/working/output/1_cap_353.png (stored 0%)
#   adding: kaggle/working/output/7_small_328.png (stored 0%)
#   adding: kaggle/working/output/5_small_389.png (stored 0%)
#   adding: kaggle/working/output/8_small_363.png (stored 0%)
#   adding: kaggle/working/output/7_cap_430.png (stored 0%)
#   adding: kaggle/working/output/1_small_45.png (stored 0%)
#   adding: kaggle/working/output/7_cap_106.png (stored 0%)
#   adding: kaggle/working/output/10_cap_18.png (stored 0%)
#   adding: kaggle/working/output/8_small_350.png (stored 0%)
#   adding: kaggle/working/output/7_small_384.png (stored 0%)
#   adding: kaggle/working/output/6_cap_401.png (stored 0%)
#   adding: kaggle/working/output/3_small_111.png (stored 0%)
#   adding: kaggle/working/output/5_cap_396.png (stored 0%)
#   adding: kaggle/working/output/6_small_445.png (stored 0%)
#   adding: kaggle/working/output/5_small_18.png (stored 0%)
#   adding: kaggle/working/output/5_cap_174.png (stored 0%)
#   adding: kaggle/working/output/10_small_459.png (stored 0%)
#   adding: kaggle/working/output/8_cap_202.png (stored 0%)
#   adding: kaggle/working/output/8_small_412.png (stored 0%)
#   adding: kaggle/working/output/6_small_344.png (stored 0%)
#   adding: kaggle/working/output/6_cap_225.png (stored 0%)
#   adding: kaggle/working/output/4_cap_74.png (stored 0%)
#   adding: kaggle/working/output/5_cap_185.png (stored 0%)
#   adding: kaggle/working/output/10_small_243.png (stored 0%)
#   adding: kaggle/working/output/5_cap_484.png (stored 0%)
#   adding: kaggle/working/output/4_cap_196.png (stored 0%)
#   adding: kaggle/working/output/3_cap_376.png (stored 0%)
#   adding: kaggle/working/output/1_small_90.png (stored 0%)
#   adding: kaggle/working/output/6_small_387.png (stored 0%)
#   adding: kaggle/working/output/8_cap_201.png (stored 0%)
#   adding: kaggle/working/output/8_small_154.png (stored 0%)
#   adding: kaggle/working/output/3_cap_347.png (stored 0%)
#   adding: kaggle/working/output/8_cap_166.png (stored 0%)
#   adding: kaggle/working/output/9_cap_169.png (stored 0%)
#   adding: kaggle/working/output/10_cap_253.png (stored 0%)
#   adding: kaggle/working/output/8_cap_444.png (stored 0%)
#   adding: kaggle/working/output/2_small_384.png (stored 0%)
#   adding: kaggle/working/output/7_small_151.png (stored 0%)
#   adding: kaggle/working/output/1_cap_414.png (stored 0%)
#   adding: kaggle/working/output/7_cap_93.png (stored 0%)
#   adding: kaggle/working/output/6_cap_377.png (stored 0%)
#   adding: kaggle/working/output/1_small_69.png (stored 0%)
#   adding: kaggle/working/output/1_small_245.png (stored 0%)
#   adding: kaggle/working/output/5_cap_403.png (stored 0%)
#   adding: kaggle/working/output/1_small_120.png (stored 0%)
#   adding: kaggle/working/output/9_cap_83.png (stored 0%)
#   adding: kaggle/working/output/6_small_47.png (stored 0%)
#   adding: kaggle/working/output/6_small_397.png (stored 0%)
#   adding: kaggle/working/output/3_cap_66.png (stored 0%)
#   adding: kaggle/working/output/6_cap_6.png (stored 0%)
#   adding: kaggle/working/output/6_small_114.png (stored 0%)
#   adding: kaggle/working/output/5_small_30.png (stored 0%)
#   adding: kaggle/working/output/5_small_134.png (stored 0%)
#   adding: kaggle/working/output/3_cap_91.png (stored 0%)
#   adding: kaggle/working/output/5_small_120.png (stored 0%)
#   adding: kaggle/working/output/3_cap_465.png (stored 0%)
#   adding: kaggle/working/output/8_small_40.png (stored 0%)
#   adding: kaggle/working/output/10_cap_119.png (stored 0%)
#   adding: kaggle/working/output/9_cap_132.png (stored 0%)
#   adding: kaggle/working/output/5_cap_342.png (stored 0%)
#   adding: kaggle/working/output/6_small_418.png (stored 0%)
#   adding: kaggle/working/output/3_small_98.png (stored 0%)
#   adding: kaggle/working/output/2_cap_40.png (stored 0%)
#   adding: kaggle/working/output/3_cap_195.png (stored 0%)
#   adding: kaggle/working/output/10_cap_388.png (stored 0%)
#   adding: kaggle/working/output/5_small_7.png (stored 0%)
#   adding: kaggle/working/output/2_cap_434.png (stored 0%)
#   adding: kaggle/working/output/10_cap_318.png (stored 0%)
#   adding: kaggle/working/output/2_small_371.png (stored 0%)
#   adding: kaggle/working/output/10_small_489.png (stored 0%)
#   adding: kaggle/working/output/4_cap_186.png (stored 0%)
#   adding: kaggle/working/output/5_small_138.png (stored 0%)
#   adding: kaggle/working/output/6_cap_210.png (stored 0%)
#   adding: kaggle/working/output/6_small_88.png (stored 0%)
#   adding: kaggle/working/output/3_cap_316.png (stored 0%)
#   adding: kaggle/working/output/10_cap_441.png (stored 0%)
#   adding: kaggle/working/output/10_cap_331.png (stored 0%)
#   adding: kaggle/working/output/10_small_194.png (stored 0%)
#   adding: kaggle/working/output/1_small_135.png (stored 0%)
#   adding: kaggle/working/output/6_cap_451.png (stored 0%)
#   adding: kaggle/working/output/7_small_174.png (stored 0%)
#   adding: kaggle/working/output/3_cap_202.png (stored 0%)
#   adding: kaggle/working/output/3_small_390.png (stored 0%)
#   adding: kaggle/working/output/4_small_150.png (stored 0%)
#   adding: kaggle/working/output/7_small_286.png (stored 0%)
#   adding: kaggle/working/output/5_small_49.png (stored 0%)
#   adding: kaggle/working/output/8_cap_475.png (stored 0%)
#   adding: kaggle/working/output/4_cap_90.png (stored 0%)
#   adding: kaggle/working/output/6_cap_465.png (stored 0%)
#   adding: kaggle/working/output/9_cap_2.png (stored 0%)
#   adding: kaggle/working/output/6_small_401.png (stored 0%)
#   adding: kaggle/working/output/8_small_103.png (stored 0%)
#   adding: kaggle/working/output/6_cap_323.png (stored 0%)
#   adding: kaggle/working/output/6_cap_310.png (stored 0%)
#   adding: kaggle/working/output/2_cap_311.png (stored 0%)
#   adding: kaggle/working/output/10_cap_437.png (stored 0%)
#   adding: kaggle/working/output/5_cap_416.png (stored 0%)
#   adding: kaggle/working/output/10_small_126.png (stored 0%)
#   adding: kaggle/working/output/1_cap_489.png (stored 0%)
#   adding: kaggle/working/output/8_cap_479.png (stored 0%)
#   adding: kaggle/working/output/9_small_51.png (stored 0%)
#   adding: kaggle/working/output/3_cap_286.png (stored 0%)
#   adding: kaggle/working/output/2_small_361.png (stored 0%)
#   adding: kaggle/working/output/10_small_394.png (stored 0%)
#   adding: kaggle/working/output/9_small_158.png (stored 0%)
#   adding: kaggle/working/output/4_small_75.png (stored 0%)
#   adding: kaggle/working/output/7_small_64.png (stored 0%)
#   adding: kaggle/working/output/3_cap_45.png (stored 0%)
#   adding: kaggle/working/output/2_small_308.png (stored 0%)
#   adding: kaggle/working/output/7_cap_61.png (stored 0%)
#   adding: kaggle/working/output/6_small_451.png (stored 0%)
#   adding: kaggle/working/output/10_small_244.png (stored 0%)
#   adding: kaggle/working/output/8_small_126.png (stored 0%)
#   adding: kaggle/working/output/5_cap_425.png (stored 0%)
#   adding: kaggle/working/output/10_small_204.png (stored 0%)
#   adding: kaggle/working/output/8_cap_155.png (stored 0%)
#   adding: kaggle/working/output/8_small_242.png (stored 0%)
#   adding: kaggle/working/output/2_cap_291.png (stored 0%)
#   adding: kaggle/working/output/8_small_480.png (stored 0%)
#   adding: kaggle/working/output/10_small_155.png (stored 0%)
#   adding: kaggle/working/output/1_small_229.png (stored 0%)
#   adding: kaggle/working/output/10_cap_137.png (stored 0%)
#   adding: kaggle/working/output/10_small_215.png (stored 0%)
#   adding: kaggle/working/output/6_small_319.png (stored 0%)
#   adding: kaggle/working/output/6_cap_43.png (stored 0%)
#   adding: kaggle/working/output/10_cap_455.png (stored 0%)
#   adding: kaggle/working/output/1_cap_411.png (stored 0%)
#   adding: kaggle/working/output/7_cap_280.png (stored 0%)
#   adding: kaggle/working/output/1_small_129.png (stored 0%)
#   adding: kaggle/working/output/1_small_446.png (stored 0%)
#   adding: kaggle/working/output/2_small_158.png (stored 0%)
#   adding: kaggle/working/output/2_cap_116.png (stored 0%)
#   adding: kaggle/working/output/6_cap_296.png (stored 0%)
#   adding: kaggle/working/output/7_cap_96.png (stored 0%)
#   adding: kaggle/working/output/1_small_136.png (stored 0%)
#   adding: kaggle/working/output/7_small_39.png (stored 0%)
#   adding: kaggle/working/output/3_cap_294.png (stored 0%)
#   adding: kaggle/working/output/1_small_78.png (stored 0%)
#   adding: kaggle/working/output/6_small_286.png (stored 0%)
#   adding: kaggle/working/output/3_small_140.png (stored 0%)
#   adding: kaggle/working/output/1_small_379.png (stored 0%)
#   adding: kaggle/working/output/2_cap_459.png (stored 0%)
#   adding: kaggle/working/output/8_small_215.png (stored 0%)
#   adding: kaggle/working/output/9_cap_113.png (stored 0%)
#   adding: kaggle/working/output/10_cap_429.png (stored 0%)
#   adding: kaggle/working/output/10_small_165.png (stored 0%)
#   adding: kaggle/working/output/9_small_101.png (stored 0%)
#   adding: kaggle/working/output/8_cap_472.png (stored 0%)
#   adding: kaggle/working/output/8_small_41.png (stored 0%)
#   adding: kaggle/working/output/5_small_321.png (stored 0%)
#   adding: kaggle/working/output/1_cap_234.png (stored 0%)
#   adding: kaggle/working/output/6_cap_448.png (stored 0%)
#   adding: kaggle/working/output/7_cap_47.png (stored 0%)
#   adding: kaggle/working/output/2_small_311.png (stored 0%)
#   adding: kaggle/working/output/2_small_151.png (stored 0%)
#   adding: kaggle/working/output/1_cap_25.png (stored 0%)
#   adding: kaggle/working/output/3_cap_35.png (stored 0%)
#   adding: kaggle/working/output/1_cap_161.png (stored 0%)
#   adding: kaggle/working/output/2_small_209.png (stored 0%)
#   adding: kaggle/working/output/1_small_167.png (stored 0%)
#   adding: kaggle/working/output/10_cap_60.png (stored 0%)
#   adding: kaggle/working/output/1_cap_398.png (stored 0%)
#   adding: kaggle/working/output/10_cap_457.png (stored 0%)
#   adding: kaggle/working/output/7_cap_269.png (stored 0%)
#   adding: kaggle/working/output/10_small_222.png (stored 0%)
#   adding: kaggle/working/output/1_cap_280.png (stored 0%)
#   adding: kaggle/working/output/6_small_450.png (stored 0%)
#   adding: kaggle/working/output/5_cap_24.png (stored 0%)
#   adding: kaggle/working/output/3_small_59.png (stored 0%)
#   adding: kaggle/working/output/6_small_299.png (stored 0%)
#   adding: kaggle/working/output/3_cap_488.png (stored 0%)
#   adding: kaggle/working/output/9_cap_176.png (stored 0%)
#   adding: kaggle/working/output/10_small_133.png (stored 0%)
#   adding: kaggle/working/output/6_small_271.png (stored 0%)
#   adding: kaggle/working/output/6_small_262.png (stored 0%)
#   adding: kaggle/working/output/10_small_177.png (stored 0%)
#   adding: kaggle/working/output/8_cap_377.png (stored 0%)
#   adding: kaggle/working/output/4_small_127.png (stored 0%)
#   adding: kaggle/working/output/2_small_293.png (stored 0%)
#   adding: kaggle/working/output/1_cap_190.png (stored 0%)
#   adding: kaggle/working/output/10_cap_448.png (stored 0%)
#   adding: kaggle/working/output/5_small_325.png (stored 0%)
#   adding: kaggle/working/output/10_small_257.png (stored 0%)
#   adding: kaggle/working/output/10_small_79.png (stored 0%)
#   adding: kaggle/working/output/7_cap_375.png (stored 0%)
#   adding: kaggle/working/output/5_cap_333.png (stored 0%)
#   adding: kaggle/working/output/10_small_298.png (stored 0%)
#   adding: kaggle/working/output/3_small_258.png (stored 0%)
#   adding: kaggle/working/output/1_cap_87.png (stored 0%)
#   adding: kaggle/working/output/3_small_414.png (stored 0%)
#   adding: kaggle/working/output/1_small_430.png (stored 0%)
#   adding: kaggle/working/output/4_cap_38.png (stored 0%)
#   adding: kaggle/working/output/5_cap_144.png (stored 0%)
#   adding: kaggle/working/output/7_small_475.png (stored 0%)
#   adding: kaggle/working/output/5_cap_47.png (stored 0%)
#   adding: kaggle/working/output/10_small_105.png (stored 0%)
#   adding: kaggle/working/output/1_cap_442.png (stored 0%)
#   adding: kaggle/working/output/1_small_232.png (stored 0%)
#   adding: kaggle/working/output/2_cap_409.png (stored 0%)
#   adding: kaggle/working/output/7_small_207.png (stored 0%)
#   adding: kaggle/working/output/6_cap_409.png (stored 0%)
#   adding: kaggle/working/output/7_cap_470.png (stored 0%)
#   adding: kaggle/working/output/8_cap_225.png (stored 0%)
#   adding: kaggle/working/output/7_small_383.png (stored 0%)
#   adding: kaggle/working/output/10_cap_20.png (stored 0%)
#   adding: kaggle/working/output/4_cap_45.png (stored 0%)
#   adding: kaggle/working/output/2_cap_427.png (stored 0%)
#   adding: kaggle/working/output/2_small_394.png (stored 0%)
#   adding: kaggle/working/output/5_cap_50.png (stored 0%)
#   adding: kaggle/working/output/10_cap_406.png (stored 0%)
#   adding: kaggle/working/output/2_cap_472.png (stored 0%)
#   adding: kaggle/working/output/7_small_421.png (stored 0%)
#   adding: kaggle/working/output/5_small_234.png (stored 0%)
#   adding: kaggle/working/output/2_small_405.png (stored 0%)
#   adding: kaggle/working/output/8_cap_222.png (stored 0%)
#   adding: kaggle/working/output/10_cap_81.png (stored 0%)
#   adding: kaggle/working/output/1_small_91.png (stored 0%)
#   adding: kaggle/working/output/8_small_414.png (stored 0%)
#   adding: kaggle/working/output/10_cap_168.png (stored 0%)
# ...
#   adding: kaggle/working/output/7_small_494.png (stored 0%)
#   adding: kaggle/working/output/10_small_11.png (stored 0%)
#   adding: kaggle/working/output/6_small_480.png (stored 0%)
#   adding: kaggle/working/output/2_cap_21.png (stored 0%)
#   adding: kaggle/working/output/10_small_428.png (stored 0%)
#   adding: kaggle/working/output/10_small_251.png (stored 0%)
#   adding: kaggle/working/output/2_small_492.png (stored 0%)
#   adding: kaggle/working/output/7_cap_406.png (stored 0%)
#   adding: kaggle/working/output/9_small_49.png (stored 0%)
#   adding: kaggle/working/output/2_cap_98.png (stored 0%)
#   adding: kaggle/working/output/2_small_213.png (stored 0%)
#   adding: kaggle/working/output/3_small_34.png (stored 0%)
#   adding: kaggle/working/output/5_small_322.png (stored 0%)
#   adding: kaggle/working/output/6_cap_156.png (stored 0%)
#   adding: kaggle/working/output/1_cap_281.png (stored 0%)
#   adding: kaggle/working/output/7_cap_296.png (stored 0%)
#   adding: kaggle/working/output/10_cap_262.png (stored 0%)
#   adding: kaggle/working/output/1_small_452.png (stored 0%)
#   adding: kaggle/working/output/6_small_101.png (stored 0%)
#   adding: kaggle/working/output/6_small_81.png (stored 0%)
#   adding: kaggle/working/output/5_cap_255.png (stored 0%)
#   adding: kaggle/working/output/5_cap_400.png (stored 0%)
#   adding: kaggle/working/output/2_cap_110.png (stored 0%)
#   adding: kaggle/working/output/5_cap_3.png (stored 0%)
#   adding: kaggle/working/output/10_small_61.png (stored 0%)
#   adding: kaggle/working/output/4_small_5.png (stored 0%)
#   adding: kaggle/working/output/6_cap_203.png (stored 0%)
#   adding: kaggle/working/output/6_cap_312.png (stored 0%)
#   adding: kaggle/working/output/10_small_339.png (stored 0%)
#   adding: kaggle/working/output/8_small_369.png (stored 0%)
#   adding: kaggle/working/output/5_cap_20.png (stored 0%)
#   adding: kaggle/working/output/3_small_401.png (stored 0%)
#   adding: kaggle/working/output/7_cap_261.png (stored 0%)
#   adding: kaggle/working/output/3_small_4.png (stored 0%)
#   adding: kaggle/working/output/3_small_367.png (stored 0%)
#   adding: kaggle/working/output/1_small_235.png (stored 0%)
#   adding: kaggle/working/output/6_cap_408.png (stored 0%)
#   adding: kaggle/working/output/10_small_221.png (stored 0%)
#   adding: kaggle/working/output/5_small_363.png (stored 0%)
#   adding: kaggle/working/output/10_small_134.png (stored 0%)
#   adding: kaggle/working/output/7_small_247.png (stored 0%)
#   adding: kaggle/working/output/1_small_43.png (stored 0%)
#   adding: kaggle/working/output/10_cap_446.png (stored 0%)
#   adding: kaggle/working/output/10_cap_387.png (stored 0%)
#   adding: kaggle/working/output/3_small_485.png (stored 0%)
#   adding: kaggle/working/output/8_cap_61.png (stored 0%)
#   adding: kaggle/working/output/4_small_97.png (stored 0%)
#   adding: kaggle/working/output/9_small_10.png (stored 0%)
#   adding: kaggle/working/output/6_small_273.png (stored 0%)
#   adding: kaggle/working/output/6_small_122.png (stored 0%)
#   adding: kaggle/working/output/10_small_217.png (stored 0%)
#   adding: kaggle/working/output/9_small_112.png (stored 0%)
#   adding: kaggle/working/output/2_small_79.png (stored 0%)
#   adding: kaggle/working/output/8_cap_63.png (stored 0%)
#   adding: kaggle/working/output/8_cap_142.png (stored 0%)
#   adding: kaggle/working/output/3_small_217.png (stored 0%)
#   adding: kaggle/working/output/7_small_267.png (stored 0%)
#   adding: kaggle/working/output/1_small_344.png (stored 0%)
#   adding: kaggle/working/output/5_cap_188.png (stored 0%)
#   adding: kaggle/working/output/5_small_4.png (stored 0%)
#   adding: kaggle/working/output/2_small_7.png (stored 0%)
#   adding: kaggle/working/output/1_cap_119.png (stored 0%)
#   adding: kaggle/working/output/2_small_45.png (stored 0%)
#   adding: kaggle/working/output/9_small_61.png (stored 0%)
#   adding: kaggle/working/output/5_small_35.png (stored 0%)
#   adding: kaggle/working/output/5_cap_234.png (stored 0%)
#   adding: kaggle/working/output/8_small_477.png (stored 0%)
#   adding: kaggle/working/output/3_small_237.png (stored 0%)
#   adding: kaggle/working/output/5_small_156.png (stored 0%)
#   adding: kaggle/working/output/7_cap_75.png (stored 0%)
#   adding: kaggle/working/output/8_small_434.png (stored 0%)
#   adding: kaggle/working/output/1_small_221.png (stored 0%)
#   adding: kaggle/working/output/6_small_44.png (stored 0%)
#   adding: kaggle/working/output/8_cap_414.png (stored 0%)
#   adding: kaggle/working/output/7_cap_284.png (stored 0%)
#   adding: kaggle/working/output/5_small_349.png (stored 0%)
#   adding: kaggle/working/output/5_cap_43.png (stored 0%)
#   adding: kaggle/working/output/7_cap_453.png (stored 0%)
#   adding: kaggle/working/output/3_cap_492.png (stored 0%)
#   adding: kaggle/working/output/8_cap_30.png (stored 0%)
#   adding: kaggle/working/output/10_cap_398.png (stored 0%)
#   adding: kaggle/working/output/2_small_242.png (stored 0%)
#   adding: kaggle/working/output/3_cap_423.png (stored 0%)
#   adding: kaggle/working/output/9_small_37.png (stored 0%)
#   adding: kaggle/working/output/2_cap_68.png (stored 0%)
#   adding: kaggle/working/output/8_cap_194.png (stored 0%)
#   adding: kaggle/working/output/5_small_483.png (stored 0%)
#   adding: kaggle/working/output/3_cap_473.png (stored 0%)
#   adding: kaggle/working/output/5_small_172.png (stored 0%)
#   adding: kaggle/working/output/10_cap_85.png (stored 0%)
#   adding: kaggle/working/output/5_cap_38.png (stored 0%)
#   adding: kaggle/working/output/1_small_359.png (stored 0%)
#   adding: kaggle/working/output/6_cap_44.png (stored 0%)
#   adding: kaggle/working/output/3_cap_332.png (stored 0%)
#   adding: kaggle/working/output/4_cap_36.png (stored 0%)
#   adding: kaggle/working/output/1_cap_248.png (stored 0%)
#   adding: kaggle/working/output/6_small_36.png (stored 0%)
#   adding: kaggle/working/output/10_cap_135.png (stored 0%)
#   adding: kaggle/working/output/2_cap_121.png (stored 0%)
#   adding: kaggle/working/output/8_cap_286.png (stored 0%)
#   adding: kaggle/working/output/7_small_38.png (stored 0%)
#   adding: kaggle/working/output/8_small_384.png (stored 0%)
#   adding: kaggle/working/output/7_cap_241.png (stored 0%)
#   adding: kaggle/working/output/9_small_40.png (stored 0%)
#   adding: kaggle/working/output/3_cap_42.png (stored 0%)
#   adding: kaggle/working/output/6_cap_369.png (stored 0%)
#   adding: kaggle/working/output/10_small_365.png (stored 0%)
#   adding: kaggle/working/output/7_small_179.png (stored 0%)
#   adding: kaggle/working/output/1_cap_496.png (stored 0%)
#   adding: kaggle/working/output/7_cap_98.png (stored 0%)
#   adding: kaggle/working/output/8_small_422.png (stored 0%)
#   adding: kaggle/working/output/5_small_258.png (stored 0%)
#   adding: kaggle/working/output/2_small_301.png (stored 0%)
#   adding: kaggle/working/output/6_cap_177.png (stored 0%)
#   adding: kaggle/working/output/2_cap_367.png (stored 0%)
#   adding: kaggle/working/output/8_cap_279.png (stored 0%)
#   adding: kaggle/working/output/3_cap_100.png (stored 0%)
#   adding: kaggle/working/output/1_cap_395.png (stored 0%)
#   adding: kaggle/working/output/9_small_168.png (stored 0%)
#   adding: kaggle/working/output/10_cap_317.png (stored 0%)
#   adding: kaggle/working/output/8_small_166.png (stored 0%)
#   adding: kaggle/working/output/7_small_461.png (stored 0%)
#   adding: kaggle/working/output/9_cap_14.png (stored 0%)
#   adding: kaggle/working/output/8_small_346.png (stored 0%)
#   adding: kaggle/working/output/6_small_179.png (stored 0%)
#   adding: kaggle/working/output/8_cap_350.png (stored 0%)
#   adding: kaggle/working/output/9_small_150.png (stored 0%)
#   adding: kaggle/working/output/5_small_208.png (stored 0%)
#   adding: kaggle/working/output/4_small_104.png (stored 0%)
#   adding: kaggle/working/output/2_cap_349.png (stored 0%)
#   adding: kaggle/working/output/5_small_283.png (stored 0%)
#   adding: kaggle/working/output/9_cap_150.png (stored 0%)
#   adding: kaggle/working/output/2_small_288.png (stored 0%)
#   adding: kaggle/working/output/10_small_226.png (stored 0%)
#   adding: kaggle/working/output/7_small_129.png (stored 0%)
#   adding: kaggle/working/output/6_small_157.png (stored 0%)
#   adding: kaggle/working/output/2_cap_64.png (stored 0%)
#   adding: kaggle/working/output/3_cap_335.png (stored 0%)
#   adding: kaggle/working/output/3_small_42.png (stored 0%)
#   adding: kaggle/working/output/8_cap_10.png (stored 0%)
#   adding: kaggle/working/output/2_cap_42.png (stored 0%)
#   adding: kaggle/working/output/4_cap_10.png (stored 0%)
#   adding: kaggle/working/output/6_cap_398.png (stored 0%)
#   adding: kaggle/working/output/1_cap_329.png (stored 0%)
#   adding: kaggle/working/output/2_cap_494.png (stored 0%)
#   adding: kaggle/working/output/2_cap_174.png (stored 0%)
#   adding: kaggle/working/output/5_small_200.png (stored 0%)
#   adding: kaggle/working/output/8_cap_321.png (stored 0%)
#   adding: kaggle/working/output/3_cap_230.png (stored 0%)
#   adding: kaggle/working/output/6_cap_76.png (stored 0%)
#   adding: kaggle/working/output/5_small_215.png (stored 0%)
#   adding: kaggle/working/output/1_small_366.png (stored 0%)
#   adding: kaggle/working/output/5_small_460.png (stored 0%)
#   adding: kaggle/working/output/8_small_267.png (stored 0%)
#   adding: kaggle/working/output/7_cap_62.png (stored 0%)
#   adding: kaggle/working/output/7_cap_368.png (stored 0%)
#   adding: kaggle/working/output/8_cap_266.png (stored 0%)
#   adding: kaggle/working/output/1_cap_450.png (stored 0%)
#   adding: kaggle/working/output/7_small_479.png (stored 0%)
#   adding: kaggle/working/output/6_small_446.png (stored 0%)
#   adding: kaggle/working/output/3_cap_308.png (stored 0%)
#   adding: kaggle/working/output/10_cap_412.png (stored 0%)
#   adding: kaggle/working/output/5_cap_467.png (stored 0%)
#   adding: kaggle/working/output/10_cap_421.png (stored 0%)
#   adding: kaggle/working/output/2_cap_46.png (stored 0%)
#   adding: kaggle/working/output/8_small_321.png (stored 0%)
#   adding: kaggle/working/output/8_small_316.png (stored 0%)
#   adding: kaggle/working/output/8_small_117.png (stored 0%)
#   adding: kaggle/working/output/7_cap_331.png (stored 0%)
#   adding: kaggle/working/output/1_cap_241.png (stored 0%)
#   adding: kaggle/working/output/4_cap_132.png (stored 0%)
#   adding: kaggle/working/output/3_cap_58.png (stored 0%)
#   adding: kaggle/working/output/3_cap_238.png (stored 0%)
#   adding: kaggle/working/output/3_cap_359.png (stored 0%)
#   adding: kaggle/working/output/7_small_283.png (stored 0%)
#   adding: kaggle/working/output/2_small_370.png (stored 0%)
#   adding: kaggle/working/output/8_cap_367.png (stored 0%)
#   adding: kaggle/working/output/9_small_46.png (stored 0%)
#   adding: kaggle/working/output/10_cap_52.png (stored 0%)
#   adding: kaggle/working/output/2_cap_246.png (stored 0%)
#   adding: kaggle/working/output/2_small_143.png (stored 0%)
#   adding: kaggle/working/output/6_cap_103.png (stored 0%)
#   adding: kaggle/working/output/10_small_285.png (stored 0%)
#   adding: kaggle/working/output/3_cap_219.png (stored 0%)
#   adding: kaggle/working/output/1_small_140.png (stored 0%)
#   adding: kaggle/working/output/2_cap_227.png (stored 0%)
#   adding: kaggle/working/output/10_cap_315.png (stored 0%)
#   adding: kaggle/working/output/2_cap_57.png (stored 0%)
#   adding: kaggle/working/output/6_small_8.png (stored 0%)
#   adding: kaggle/working/output/7_small_342.png (stored 0%)
#   adding: kaggle/working/output/3_small_110.png (stored 0%)
#   adding: kaggle/working/output/6_cap_245.png (stored 0%)
#   adding: kaggle/working/output/8_cap_473.png (stored 0%)
#   adding: kaggle/working/output/8_small_77.png (stored 0%)
#   adding: kaggle/working/output/10_cap_335.png (stored 0%)
#   adding: kaggle/working/output/1_cap_422.png (stored 0%)
#   adding: kaggle/working/output/3_cap_448.png (stored 0%)
#   adding: kaggle/working/output/9_small_22.png (stored 0%)
#   adding: kaggle/working/output/2_small_274.png (stored 0%)
#   adding: kaggle/working/output/2_cap_273.png (stored 0%)
#   adding: kaggle/working/output/5_small_23.png (stored 0%)
#   adding: kaggle/working/output/10_small_234.png (stored 0%)
#   adding: kaggle/working/output/7_small_53.png (stored 0%)
#   adding: kaggle/working/output/3_small_70.png (stored 0%)
#   adding: kaggle/working/output/5_cap_196.png (stored 0%)
#   adding: kaggle/working/output/2_cap_218.png (stored 0%)
#   adding: kaggle/working/output/2_cap_285.png (stored 0%)
#   adding: kaggle/working/output/1_cap_355.png (stored 0%)
#   adding: kaggle/working/output/3_small_245.png (stored 0%)
#   adding: kaggle/working/output/7_cap_364.png (stored 0%)
#   adding: kaggle/working/output/3_cap_263.png (stored 0%)
#   adding: kaggle/working/output/2_cap_102.png (stored 0%)
#   adding: kaggle/working/output/1_small_289.png (stored 0%)
#   adding: kaggle/working/output/7_cap_474.png (stored 0%)
#   adding: kaggle/working/output/7_cap_420.png (stored 0%)
#   adding: kaggle/working/output/8_small_246.png (stored 0%)
#   adding: kaggle/working/output/5_small_65.png (stored 0%)
#   adding: kaggle/working/output/1_cap_12.png (stored 0%)
#   adding: kaggle/working/output/4_cap_125.png (stored 0%)
#   adding: kaggle/working/output/5_small_47.png (stored 0%)
#   adding: kaggle/working/output/5_small_19.png (stored 0%)
#   adding: kaggle/working/output/2_cap_355.png (stored 0%)
#   adding: kaggle/working/output/5_cap_153.png (stored 0%)
#   adding: kaggle/working/output/10_cap_397.png (stored 0%)
#   adding: kaggle/working/output/8_cap_407.png (stored 0%)
#   adding: kaggle/working/output/9_small_100.png (stored 0%)
#   adding: kaggle/working/output/5_small_54.png (stored 0%)
#   adding: kaggle/working/output/3_small_153.png (stored 0%)
#   adding: kaggle/working/output/2_small_382.png (stored 0%)
#   adding: kaggle/working/output/4_small_60.png (stored 0%)
#   adding: kaggle/working/output/6_small_121.png (stored 0%)
#   adding: kaggle/working/output/8_cap_105.png (stored 0%)
#   adding: kaggle/working/output/7_small_215.png (stored 0%)
#   adding: kaggle/working/output/7_small_375.png (stored 0%)
#   adding: kaggle/working/output/2_small_150.png (stored 0%)
#   adding: kaggle/working/output/2_cap_479.png (stored 0%)
#   adding: kaggle/working/output/1_cap_318.png (stored 0%)
#   adding: kaggle/working/output/7_small_250.png (stored 0%)
#   adding: kaggle/working/output/3_small_432.png (stored 0%)
#   adding: kaggle/working/output/2_cap_74.png (stored 0%)
#   adding: kaggle/working/output/7_cap_346.png (stored 0%)
#   adding: kaggle/working/output/6_cap_318.png (stored 0%)
#   adding: kaggle/working/output/7_cap_225.png (stored 0%)
#   adding: kaggle/working/output/6_small_464.png (stored 0%)
#   adding: kaggle/working/output/3_small_378.png (stored 0%)
#   adding: kaggle/working/output/8_cap_253.png (stored 0%)
#   adding: kaggle/working/output/10_small_379.png (stored 0%)
#   adding: kaggle/working/output/1_cap_449.png (stored 0%)
#   adding: kaggle/working/output/9_cap_195.png (stored 0%)
#   adding: kaggle/working/output/6_cap_95.png (stored 0%)
#   adding: kaggle/working/output/4_small_83.png (stored 0%)
#   adding: kaggle/working/output/6_small_129.png (stored 0%)
#   adding: kaggle/working/output/1_small_42.png (stored 0%)
#   adding: kaggle/working/output/4_small_47.png (stored 0%)
#   adding: kaggle/working/output/1_cap_52.png (stored 0%)
#   adding: kaggle/working/output/3_small_107.png (stored 0%)
#   adding: kaggle/working/output/7_small_160.png (stored 0%)
#   adding: kaggle/working/output/7_small_28.png (stored 0%)
#   adding: kaggle/working/output/7_cap_95.png (stored 0%)
#   adding: kaggle/working/output/6_small_471.png (stored 0%)
#   adding: kaggle/working/output/3_small_341.png (stored 0%)
#   adding: kaggle/working/output/10_cap_341.png (stored 0%)
#   adding: kaggle/working/output/3_cap_125.png (stored 0%)
#   adding: kaggle/working/output/5_cap_324.png (stored 0%)
#   adding: kaggle/working/output/7_cap_359.png (stored 0%)
#   adding: kaggle/working/output/1_small_365.png (stored 0%)
#   adding: kaggle/working/output/6_cap_131.png (stored 0%)
#   adding: kaggle/working/output/6_cap_53.png (stored 0%)
#   adding: kaggle/working/output/7_cap_393.png (stored 0%)
#   adding: kaggle/working/output/1_small_68.png (stored 0%)
#   adding: kaggle/working/output/3_small_499.png (stored 0%)
#   adding: kaggle/working/output/7_small_97.png (stored 0%)
