# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import json
import sys
import matplotlib.pyplot as plt
from timeit import default_timer as timer

# %%
ds = '2'

# %%
# ds = input('Which dataset do you want to run on? Enter 1 for \'Raw\', 2 for \'EMNIST\' \
# or 3 for \'Chars74K')

# %%
i = 0

while i == 0:
    if ds == '1':
        directory = "../input/yaromnist-dataset/Raw Handwritten Roman Numerals Dataset"
        user_data = directory + "/train"
        valid_data = directory + "/val"
        test_data = directory + "/test" # this can be the label book, or any other test set you create
        i = 1
    elif ds == '2':
        directory = "../input/emnistbased-handwritten-roman-numerals/500_each_EMNIST-based-Roman"
        user_data = directory + "/train"
        valid_data = directory + "/val"
        test_data = directory + "/test" # this can be the label book, or any other test set you create
        i = 1
    elif ds == '3':
        directory = "../input/basedonenglishhandwrittencharactersmodified/Based-Chars74K-image-dataset-Roman"
        user_data = directory + "/train"
        valid_data = directory + "/val"
        test_data = directory + "/test" # this can be the label book, or any other test set you create
        i = 1
    else: ds = input('Sorry, try again!')

# %%
### DO NOT MODIFY BELOW THIS LINE, THIS IS THE FIXED MODEL ###
batch_size = 8
tf.random.set_seed(123)


if __name__ == "__main__":
    train = tf.keras.preprocessing.image_dataset_from_directory(
        user_data,
        labels="inferred",
        label_mode="categorical",
        class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
        shuffle=True,
        seed=123,
        batch_size=batch_size,
        image_size=(32, 32),
    )

    valid = tf.keras.preprocessing.image_dataset_from_directory(
        valid_data,
        labels="inferred",
        label_mode="categorical",
        class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
        shuffle=True,
        seed=123,
        batch_size=batch_size,
        image_size=(32, 32),
    )

    total_length = ((train.cardinality() + valid.cardinality()) * batch_size).numpy()
    if total_length > 10_000:
        print(f"Dataset size larger than 10,000. Got {total_length} examples")
        sys.exit()

    test = tf.keras.preprocessing.image_dataset_from_directory(
        test_data,
        labels="inferred",
        label_mode="categorical",
        class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
        shuffle=False,
        seed=123,
        batch_size=batch_size,
        image_size=(32, 32),
    )
    
    start = timer() # Not in original code

    base_model = tf.keras.applications.ResNet50(
        input_shape=(32, 32, 3),
        include_top=False,
        weights=None,
    )
    base_model = tf.keras.Model(
        base_model.inputs, outputs=[base_model.get_layer("conv2_block3_out").output]
    )

    inputs = tf.keras.Input(shape=(32, 32, 3))
    x = tf.keras.applications.resnet.preprocess_input(inputs)
    x = base_model(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(10)(x)
    model = tf.keras.Model(inputs, x)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr=0.0001),
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"],
    )
    model.summary()
    loss_0, acc_0 = model.evaluate(valid)
    print(f"loss {loss_0}, acc {acc_0}")

    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        "best_model",
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        train,
        validation_data=valid,
        epochs=100,
        callbacks=[checkpoint],
    )

    model.load_weights("best_model")

    loss, acc = model.evaluate(valid)
    print(f"final loss {loss}, final acc {acc}")

    test_loss, test_acc = model.evaluate(test)
    print(f"test loss {test_loss}, test acc {test_acc}")
    
    end = timer() # Not in original code
    print("Time taken = " + str(end - start) + ' s') # Not in original code
# Out:
# Found 6895 files belonging to 10 classes.
# User settings:
#
#    KMP_AFFINITY=granularity=fine,noverbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=false
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='noverbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-02-14 18:53:29.601088: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Found 1969 files belonging to 10 classes.
# Found 985 files belonging to 10 classes.
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# tf.__operators__.getitem (Sl (None, 32, 32, 3)         0
# _________________________________________________________________
# tf.nn.bias_add (TFOpLambda)  (None, 32, 32, 3)         0
# _________________________________________________________________
# model (Functional)           (None, 8, 8, 256)         229760
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                2570
# =================================================================
# Total params: 232,330
# Trainable params: 229,386
# Non-trainable params: 2,944
# _________________________________________________________________
# 2022-02-14 18:53:32.052725: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 247/247 [==============================] - 4s 11ms/step - loss: 33.9756 - accuracy: 0.1006
# loss 33.97561264038086, acc 0.10055866092443466
# Epoch 1/100
# 862/862 [==============================] - 28s 30ms/step - loss: 0.5763 - accuracy: 0.8619 - val_loss: 0.1184 - val_accuracy: 0.9756
# Epoch 2/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.1368 - accuracy: 0.9682 - val_loss: 0.1348 - val_accuracy: 0.9619
# Epoch 3/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0848 - accuracy: 0.9796 - val_loss: 0.0537 - val_accuracy: 0.9863
# Epoch 4/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0533 - accuracy: 0.9887 - val_loss: 0.1104 - val_accuracy: 0.9680
# Epoch 5/100
# 862/862 [==============================] - 24s 27ms/step - loss: 0.0494 - accuracy: 0.9878 - val_loss: 0.0668 - val_accuracy: 0.9807
# Epoch 6/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0340 - accuracy: 0.9917 - val_loss: 0.0323 - val_accuracy: 0.9914
# Epoch 7/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0262 - accuracy: 0.9939 - val_loss: 0.0405 - val_accuracy: 0.9883
# Epoch 8/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0195 - accuracy: 0.9967 - val_loss: 0.0668 - val_accuracy: 0.9817
# Epoch 9/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0216 - accuracy: 0.9948 - val_loss: 0.0369 - val_accuracy: 0.9898
# Epoch 10/100
# 862/862 [==============================] - 25s 28ms/step - loss: 0.0148 - accuracy: 0.9972 - val_loss: 0.0762 - val_accuracy: 0.9782
# Epoch 11/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0175 - accuracy: 0.9956 - val_loss: 0.0426 - val_accuracy: 0.9858
# Epoch 12/100
# 862/862 [==============================] - 25s 28ms/step - loss: 0.0159 - accuracy: 0.9959 - val_loss: 0.0341 - val_accuracy: 0.9919
# Epoch 13/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0131 - accuracy: 0.9972 - val_loss: 0.0364 - val_accuracy: 0.9888
# Epoch 14/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0161 - accuracy: 0.9964 - val_loss: 0.0406 - val_accuracy: 0.9893
# Epoch 15/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0140 - accuracy: 0.9961 - val_loss: 0.0500 - val_accuracy: 0.9868
# Epoch 16/100
# 862/862 [==============================] - 25s 30ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.0327 - val_accuracy: 0.9904
# Epoch 17/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0054 - accuracy: 0.9996 - val_loss: 0.0341 - val_accuracy: 0.9914
# Epoch 18/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 0.0380 - val_accuracy: 0.9904
# Epoch 19/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0061 - accuracy: 0.9988 - val_loss: 0.0771 - val_accuracy: 0.9807
# Epoch 20/100
# 862/862 [==============================] - 25s 28ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0425 - val_accuracy: 0.9878
# Epoch 21/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.0286 - val_accuracy: 0.9898
# Epoch 22/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0355 - val_accuracy: 0.9909
# Epoch 23/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0360 - val_accuracy: 0.9929
# Epoch 24/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0552 - val_accuracy: 0.9858
# Epoch 25/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.0399 - val_accuracy: 0.9898
# Epoch 26/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.2876 - val_accuracy: 0.9274
# Epoch 27/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0355 - val_accuracy: 0.9919
# Epoch 28/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0562 - val_accuracy: 0.9883
# Epoch 29/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0323 - val_accuracy: 0.9909
# Epoch 30/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.0317 - val_accuracy: 0.9909
# Epoch 31/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0472 - val_accuracy: 0.9878
# Epoch 32/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.0414 - val_accuracy: 0.9893
# Epoch 33/100
# 862/862 [==============================] - 24s 27ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0354 - val_accuracy: 0.9919
# Epoch 34/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0447 - val_accuracy: 0.9893
# Epoch 35/100
# 862/862 [==============================] - 24s 27ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.0378 - val_accuracy: 0.9904
# Epoch 36/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0287 - val_accuracy: 0.9929
# Epoch 37/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0405 - val_accuracy: 0.9888
# Epoch 38/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0518 - val_accuracy: 0.9873
# Epoch 39/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0449 - val_accuracy: 0.9868
# Epoch 40/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0444 - val_accuracy: 0.9919
# Epoch 41/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0056 - accuracy: 0.9975 - val_loss: 0.0430 - val_accuracy: 0.9904
# Epoch 42/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0390 - val_accuracy: 0.9904
# Epoch 43/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0345 - val_accuracy: 0.9929
# Epoch 44/100
# 862/862 [==============================] - 25s 29ms/step - loss: 4.8940e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9919
# Epoch 45/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.0388 - val_accuracy: 0.9914
# Epoch 46/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0496 - val_accuracy: 0.9914
# Epoch 47/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.0359 - val_accuracy: 0.9919
# Epoch 48/100
# 862/862 [==============================] - 27s 31ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.0347 - val_accuracy: 0.9914
# Epoch 49/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0354 - val_accuracy: 0.9914
# Epoch 50/100
# 862/862 [==============================] - 27s 31ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0425 - val_accuracy: 0.9898
# Epoch 51/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0494 - val_accuracy: 0.9909
# Epoch 52/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0349 - val_accuracy: 0.9914
# Epoch 53/100
# 862/862 [==============================] - 27s 31ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0352 - val_accuracy: 0.9929
# Epoch 54/100
# 862/862 [==============================] - 25s 30ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0408 - val_accuracy: 0.9914
# Epoch 55/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.0389 - val_accuracy: 0.9909
# Epoch 56/100
# 862/862 [==============================] - 27s 32ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0465 - val_accuracy: 0.9909
# Epoch 57/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.0334 - val_accuracy: 0.9929
# Epoch 58/100
# 862/862 [==============================] - 27s 31ms/step - loss: 3.7046e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9914
# Epoch 59/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0333 - val_accuracy: 0.9914
# Epoch 60/100
# 862/862 [==============================] - 27s 32ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0376 - val_accuracy: 0.9914
# Epoch 61/100
# 862/862 [==============================] - 27s 31ms/step - loss: 0.0035 - accuracy: 0.9983 - val_loss: 0.0867 - val_accuracy: 0.9711
# Epoch 62/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0429 - val_accuracy: 0.9909
# Epoch 63/100
# 862/862 [==============================] - 28s 33ms/step - loss: 8.3145e-04 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.9919
# Epoch 64/100
# 862/862 [==============================] - 27s 31ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0427 - val_accuracy: 0.9898
# Epoch 65/100
# 862/862 [==============================] - 26s 31ms/step - loss: 6.7892e-04 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9929
# Epoch 66/100
# 862/862 [==============================] - 28s 32ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0334 - val_accuracy: 0.9934
# Epoch 67/100
# 862/862 [==============================] - 26s 31ms/step - loss: 5.8040e-04 - accuracy: 0.9999 - val_loss: 0.0497 - val_accuracy: 0.9878
# Epoch 68/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.0600 - val_accuracy: 0.9873
# Epoch 69/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.0363 - val_accuracy: 0.9909
# Epoch 70/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0319 - val_accuracy: 0.9934
# Epoch 71/100
# 862/862 [==============================] - 25s 29ms/step - loss: 7.4611e-04 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9939
# Epoch 72/100
# 862/862 [==============================] - 25s 29ms/step - loss: 5.2368e-04 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9934
# Epoch 73/100
# 862/862 [==============================] - 24s 28ms/step - loss: 9.1510e-04 - accuracy: 0.9996 - val_loss: 0.0401 - val_accuracy: 0.9914
# Epoch 74/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0592 - val_accuracy: 0.9904
# Epoch 75/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0634 - val_accuracy: 0.9853
# Epoch 76/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0380 - val_accuracy: 0.9919
# Epoch 77/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0382 - val_accuracy: 0.9919
# Epoch 78/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.0387 - val_accuracy: 0.9873
# Epoch 79/100
# 862/862 [==============================] - 25s 29ms/step - loss: 5.4256e-04 - accuracy: 1.0000 - val_loss: 0.0551 - val_accuracy: 0.9898
# Epoch 80/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0392 - val_accuracy: 0.9909
# Epoch 81/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0333 - val_accuracy: 0.9929
# Epoch 82/100
# 862/862 [==============================] - 25s 29ms/step - loss: 4.8739e-04 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9924
# Epoch 83/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.2025 - val_accuracy: 0.9512
# Epoch 84/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0435 - val_accuracy: 0.9904
# Epoch 85/100
# 862/862 [==============================] - 24s 28ms/step - loss: 8.0398e-04 - accuracy: 0.9999 - val_loss: 0.0312 - val_accuracy: 0.9939
# Epoch 86/100
# 862/862 [==============================] - 25s 28ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0729 - val_accuracy: 0.9873
# Epoch 87/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0290 - val_accuracy: 0.9909
# Epoch 88/100
# 862/862 [==============================] - 27s 31ms/step - loss: 3.7355e-04 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9944
# Epoch 89/100
# 862/862 [==============================] - 25s 29ms/step - loss: 4.6371e-04 - accuracy: 0.9999 - val_loss: 0.0295 - val_accuracy: 0.9934
# Epoch 90/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0442 - val_accuracy: 0.9904
# Epoch 91/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0546 - val_accuracy: 0.9858
# Epoch 92/100
# 862/862 [==============================] - 27s 31ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0638 - val_accuracy: 0.9873
# Epoch 93/100
# 862/862 [==============================] - 28s 33ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0382 - val_accuracy: 0.9934
# Epoch 94/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.0471 - val_accuracy: 0.9919
# Epoch 95/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.0491 - val_accuracy: 0.9893
# Epoch 96/100
# 862/862 [==============================] - 26s 30ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0403 - val_accuracy: 0.9919
# Epoch 97/100
# 862/862 [==============================] - 26s 31ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0415 - val_accuracy: 0.9929
# Epoch 98/100
# 862/862 [==============================] - 25s 29ms/step - loss: 2.8368e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9939
# Epoch 99/100
# 862/862 [==============================] - 25s 29ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.0388 - val_accuracy: 0.9904
# Epoch 100/100
# 862/862 [==============================] - 24s 28ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0620 - val_accuracy: 0.9924
# 247/247 [==============================] - 2s 10ms/step - loss: 0.0331 - accuracy: 0.9944
# final loss 0.03311742842197418, final acc 0.994413435459137
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0203 - accuracy: 0.9939
# test loss 0.020324120298027992, test acc 0.9939086437225342
# Time taken = 2889.025589407 s

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        min_delta=0,
        patience=10,
        verbose=0,
        mode="auto",
        baseline=None,
        restore_best_weights=False,
    )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
        "best_model",
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
    )

# %%
start_2 = timer()

base_model_2 = tf.keras.applications.ResNet50(weights=None, input_shape=(32, 32, 3), classes=10)

inputs_2 = tf.keras.Input(shape=(32, 32, 3))
x_2 = tf.keras.applications.resnet.preprocess_input(inputs_2)
x_2 = base_model_2(x_2)
model_2 = tf.keras.Model(inputs_2, x_2)

model_2.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss=tf.keras.losses.CategoricalCrossentropy(),#from_logits=True),
        metrics=["accuracy"]
    )
 
loss_0, acc_0 = model_2.evaluate(valid)
print(f"loss {loss_0}, acc {acc_0}")
    

history_2 = model_2.fit(
        train,
        validation_data=valid,
        epochs=100,
        callbacks=[stopping, checkpoint]
)

model_2.load_weights("best_model")

loss, acc = model_2.evaluate(valid)
print(f"final loss {loss}, final acc {acc}")

test_loss, test_acc = model_2.evaluate(test)
print(f"test loss {test_loss}, test acc {test_acc}")
    
end_2 = timer()
print("Time taken = " + str(end_2 - start_2) + ' s')
# Out:
# 247/247 [==============================] - 18s 64ms/step - loss: 6.9880 - accuracy: 0.1133
# loss 6.988008975982666, acc 0.11325545608997345
# Epoch 1/100
# 862/862 [==============================] - 256s 289ms/step - loss: 2.2269 - accuracy: 0.3442 - val_loss: 1.8912 - val_accuracy: 0.4804
# Epoch 2/100
# 862/862 [==============================] - 250s 290ms/step - loss: 1.3635 - accuracy: 0.5756 - val_loss: 0.9326 - val_accuracy: 0.6948
# Epoch 3/100
# 862/862 [==============================] - 264s 306ms/step - loss: 0.9585 - accuracy: 0.7044 - val_loss: 0.6468 - val_accuracy: 0.7862
# Epoch 4/100
# 862/862 [==============================] - 255s 296ms/step - loss: 0.6474 - accuracy: 0.8020 - val_loss: 0.4743 - val_accuracy: 0.8451
# Epoch 5/100
# 862/862 [==============================] - 270s 314ms/step - loss: 0.4435 - accuracy: 0.8654 - val_loss: 0.3421 - val_accuracy: 0.8939
# Epoch 6/100
# 862/862 [==============================] - 255s 295ms/step - loss: 0.3106 - accuracy: 0.9027 - val_loss: 0.3331 - val_accuracy: 0.8994
# Epoch 7/100
# 862/862 [==============================] - 268s 311ms/step - loss: 0.2470 - accuracy: 0.9284 - val_loss: 0.2942 - val_accuracy: 0.9167
# Epoch 8/100
# 862/862 [==============================] - 252s 292ms/step - loss: 0.2395 - accuracy: 0.9295 - val_loss: 0.1929 - val_accuracy: 0.9380
# Epoch 9/100
# 862/862 [==============================] - 257s 298ms/step - loss: 0.1879 - accuracy: 0.9440 - val_loss: 0.1556 - val_accuracy: 0.9584
# Epoch 10/100
# 862/862 [==============================] - 270s 314ms/step - loss: 0.1718 - accuracy: 0.9517 - val_loss: 0.1439 - val_accuracy: 0.9604
# Epoch 11/100
# 862/862 [==============================] - 255s 295ms/step - loss: 0.1680 - accuracy: 0.9545 - val_loss: 0.1746 - val_accuracy: 0.9477
# Epoch 12/100
# 862/862 [==============================] - 270s 313ms/step - loss: 0.1220 - accuracy: 0.9679 - val_loss: 0.1320 - val_accuracy: 0.9619
# Epoch 13/100
# 862/862 [==============================] - 260s 302ms/step - loss: 0.1216 - accuracy: 0.9662 - val_loss: 0.1572 - val_accuracy: 0.9558
# Epoch 14/100
# 862/862 [==============================] - 262s 304ms/step - loss: 0.0993 - accuracy: 0.9743 - val_loss: 0.1403 - val_accuracy: 0.9655
# Epoch 15/100
# 862/862 [==============================] - 276s 320ms/step - loss: 0.1038 - accuracy: 0.9751 - val_loss: 0.3758 - val_accuracy: 0.9314
# Epoch 16/100
# 862/862 [==============================] - 267s 309ms/step - loss: 0.0812 - accuracy: 0.9759 - val_loss: 0.1034 - val_accuracy: 0.9761
# Epoch 17/100
# 862/862 [==============================] - 264s 306ms/step - loss: 0.1070 - accuracy: 0.9720 - val_loss: 0.1059 - val_accuracy: 0.9711
# Epoch 18/100
# 862/862 [==============================] - 262s 304ms/step - loss: 0.0648 - accuracy: 0.9830 - val_loss: 0.0753 - val_accuracy: 0.9843
# Epoch 19/100
# 862/862 [==============================] - 263s 305ms/step - loss: 0.0502 - accuracy: 0.9846 - val_loss: 0.3638 - val_accuracy: 0.9152
# Epoch 20/100
# 862/862 [==============================] - 267s 310ms/step - loss: 0.0603 - accuracy: 0.9846 - val_loss: 0.0784 - val_accuracy: 0.9848
# Epoch 21/100
# 862/862 [==============================] - 269s 312ms/step - loss: 0.0726 - accuracy: 0.9817 - val_loss: 0.0699 - val_accuracy: 0.9848
# Epoch 22/100
# 862/862 [==============================] - 266s 309ms/step - loss: 0.0381 - accuracy: 0.9900 - val_loss: 0.1049 - val_accuracy: 0.9741
# Epoch 23/100
# 862/862 [==============================] - 259s 300ms/step - loss: 0.0747 - accuracy: 0.9836 - val_loss: 0.0708 - val_accuracy: 0.9812
# Epoch 24/100
# 862/862 [==============================] - 262s 304ms/step - loss: 0.0530 - accuracy: 0.9862 - val_loss: 0.0817 - val_accuracy: 0.9843
# Epoch 25/100
# 862/862 [==============================] - 267s 310ms/step - loss: 0.0248 - accuracy: 0.9930 - val_loss: 0.1013 - val_accuracy: 0.9807
# Epoch 26/100
# 862/862 [==============================] - 269s 312ms/step - loss: 0.0245 - accuracy: 0.9938 - val_loss: 0.0992 - val_accuracy: 0.9792
# Epoch 27/100
# 862/862 [==============================] - 270s 313ms/step - loss: 0.0199 - accuracy: 0.9943 - val_loss: 0.1031 - val_accuracy: 0.9771
# Epoch 28/100
# 862/862 [==============================] - 268s 311ms/step - loss: 0.0597 - accuracy: 0.9843 - val_loss: 0.0755 - val_accuracy: 0.9858
# Epoch 29/100
# 862/862 [==============================] - 279s 324ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0799 - val_accuracy: 0.9853
# Epoch 30/100
# 862/862 [==============================] - 276s 320ms/step - loss: 0.0330 - accuracy: 0.9926 - val_loss: 0.1184 - val_accuracy: 0.9812
# Epoch 31/100
# 862/862 [==============================] - 269s 312ms/step - loss: 0.0442 - accuracy: 0.9891 - val_loss: 0.0854 - val_accuracy: 0.9832
# Epoch 32/100
# 862/862 [==============================] - 268s 311ms/step - loss: 0.0182 - accuracy: 0.9961 - val_loss: 0.0726 - val_accuracy: 0.9843
# Epoch 33/100
# 862/862 [==============================] - 251s 292ms/step - loss: 0.0319 - accuracy: 0.9930 - val_loss: 0.0825 - val_accuracy: 0.9837
# Epoch 34/100
# 862/862 [==============================] - 266s 308ms/step - loss: 0.0230 - accuracy: 0.9936 - val_loss: 0.5412 - val_accuracy: 0.9421
# Epoch 35/100
# 862/862 [==============================] - 272s 316ms/step - loss: 0.0093 - accuracy: 0.9978 - val_loss: 0.1341 - val_accuracy: 0.9736
# Epoch 36/100
# 862/862 [==============================] - 275s 319ms/step - loss: 0.0268 - accuracy: 0.9941 - val_loss: 0.0938 - val_accuracy: 0.9792
# Epoch 37/100
# 862/862 [==============================] - 263s 306ms/step - loss: 0.0211 - accuracy: 0.9951 - val_loss: 0.0993 - val_accuracy: 0.9802
# Epoch 38/100
# 862/862 [==============================] - 262s 304ms/step - loss: 0.0458 - accuracy: 0.9885 - val_loss: 0.0853 - val_accuracy: 0.9822
# 247/247 [==============================] - 16s 62ms/step - loss: 0.0755 - accuracy: 0.9858
# final loss 0.07549551129341125, final acc 0.9857795834541321
# 124/124 [==============================] - 8s 64ms/step - loss: 0.0455 - accuracy: 0.9909
# test loss 0.04551849886775017, test acc 0.9908629655838013
# Time taken = 10190.317964104 s

# %%
# summarize history for accuracy
plt.plot(history_2.history['accuracy'])
plt.plot(history_2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
start_3 = timer()

model_3 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(32, 32, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
    
])

model_3.compile(
        optimizer=tf.keras.optimizers.Adam(lr=0.0001),
        loss=tf.keras.losses.CategoricalCrossentropy(),
        metrics=["accuracy"]
    )

history_3 = model_3.fit(
        train,
        validation_data=valid,
        epochs=100,
        callbacks=[stopping, checkpoint]
    )

model_3.load_weights("best_model")

loss, acc = model_3.evaluate(valid)
print(f"final loss {loss}, final acc {acc}")

test_loss, test_acc = model_3.evaluate(test)
print(f"test loss {test_loss}, test acc {test_acc}")

end_3 = timer()
print("Time taken = " + str(end_3 - start_3) + ' s')
# Out:
# Epoch 1/100
# 862/862 [==============================] - 9s 10ms/step - loss: 2.1904 - accuracy: 0.5910 - val_loss: 0.7078 - val_accuracy: 0.8197
# Epoch 2/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.4982 - accuracy: 0.8651 - val_loss: 0.4186 - val_accuracy: 0.8939
# Epoch 3/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.2676 - accuracy: 0.9221 - val_loss: 0.3155 - val_accuracy: 0.9167
# Epoch 4/100
# 862/862 [==============================] - 8s 10ms/step - loss: 0.1656 - accuracy: 0.9511 - val_loss: 0.2838 - val_accuracy: 0.9269
# Epoch 5/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.1048 - accuracy: 0.9659 - val_loss: 0.2233 - val_accuracy: 0.9457
# Epoch 6/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0844 - accuracy: 0.9707 - val_loss: 0.1782 - val_accuracy: 0.9543
# Epoch 7/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0601 - accuracy: 0.9787 - val_loss: 0.1620 - val_accuracy: 0.9655
# Epoch 8/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0379 - accuracy: 0.9858 - val_loss: 0.1758 - val_accuracy: 0.9665
# Epoch 9/100
# 862/862 [==============================] - 8s 10ms/step - loss: 0.0436 - accuracy: 0.9849 - val_loss: 0.1912 - val_accuracy: 0.9599
# Epoch 10/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0165 - accuracy: 0.9954 - val_loss: 0.1842 - val_accuracy: 0.9675
# Epoch 11/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0425 - accuracy: 0.9864 - val_loss: 0.1825 - val_accuracy: 0.9721
# Epoch 12/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0201 - accuracy: 0.9932 - val_loss: 0.2389 - val_accuracy: 0.9634
# Epoch 13/100
# 862/862 [==============================] - 8s 10ms/step - loss: 0.0384 - accuracy: 0.9881 - val_loss: 0.1829 - val_accuracy: 0.9741
# Epoch 14/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0275 - accuracy: 0.9920 - val_loss: 0.1986 - val_accuracy: 0.9680
# Epoch 15/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0048 - accuracy: 0.9990 - val_loss: 0.1779 - val_accuracy: 0.9726
# Epoch 16/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0274 - accuracy: 0.9932 - val_loss: 0.1948 - val_accuracy: 0.9660
# Epoch 17/100
# 862/862 [==============================] - 8s 10ms/step - loss: 0.0197 - accuracy: 0.9929 - val_loss: 0.1982 - val_accuracy: 0.9665
# Epoch 18/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.2326 - val_accuracy: 0.9660
# Epoch 19/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0122 - accuracy: 0.9954 - val_loss: 0.3093 - val_accuracy: 0.9472
# Epoch 20/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0239 - accuracy: 0.9925 - val_loss: 0.1893 - val_accuracy: 0.9695
# Epoch 21/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0149 - accuracy: 0.9954 - val_loss: 0.2336 - val_accuracy: 0.9639
# Epoch 22/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0156 - accuracy: 0.9951 - val_loss: 0.2891 - val_accuracy: 0.9538
# Epoch 23/100
# 862/862 [==============================] - 8s 9ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.2425 - val_accuracy: 0.9705
# 247/247 [==============================] - 1s 4ms/step - loss: 0.2425 - accuracy: 0.9705
# final loss 0.2424686998128891, final acc 0.9705434441566467
# 124/124 [==============================] - 1s 4ms/step - loss: 0.1303 - accuracy: 0.9787
# test loss 0.13031505048274994, test acc 0.9786801934242249
# Time taken = 186.81453419699938 s

# %%
# summarize history for accuracy
plt.plot(history_3.history['accuracy'])
plt.plot(history_3.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
